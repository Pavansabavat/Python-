# %%
import pandas as pd
import numpy as np

# %%
## Type Conversion
series1 = pd.Series([100, 110, 120, 130, 140])
series2 = pd.Series(['ram','kumar','sowjanya','kishna','john'])
df=pd.DataFrame({'Id': series1,'Name':series2})

# %%
df['Salary'] = ['10k','20k','30k','40k','50k']
df
# Out:
#     Id      Name Salary
# 0  100       ram    10k
# 1  110     kumar    20k
# 2  120  sowjanya    30k
# 3  130    kishna    40k
# 4  140      john    50k

# %% [markdown]
# Note: in pandas version > = 0.20.0, ix is deprecated . Thus, useloc and iloc instead.
#
# loc — gets rows (or columns) with particular labels from the index.
# iloc — gets rows (or columns) at particular positions in the index (so it only takes integers).
# ix — usually behaves like loc but falls back to behaving like iloc if a label is not present in the index.

# %%
import pandas as pd

df_titanic = pd.read_csv("D:\Kalyan\InnovativeResearchLabs\Batch_Data Analysis_\\Titanic.csv")
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_titanic["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
len(df_titanic["Sex"].unique())
# Out:
# 2

# %%
df_titanic["Sex"].nunique()
# Out:
# 2

# %% [markdown]
# 1. Age is greater than 40
# 2. Age between 40 and 50

# %%
df_titanic["Age"]>40
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: Age, Length: 418, dtype: bool

# %%
df = df_titanic[df_titanic["Age"]>40]

# %%
df.head()
# Out:
#     PassengerId  Pclass                                               Name  \
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 11          903       1                         Jones, Mr. Charles Cresson
# 13          905       2                               Howard, Mr. Benjamin
# 14          906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
#
#        Sex   Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# 1   female  47.0      1      0       363272   7.0000   NaN        S
# 2     male  62.0      0      0       240276   9.6875   NaN        Q
# 11    male  46.0      0      0          694  26.0000   NaN        S
# 13    male  63.0      1      0        24065  26.0000   NaN        S
# 14  female  47.0      1      0  W.E.P. 5734  61.1750   E31        S

# %%
df1 = df_titanic[(df_titanic["Age"]>40) & (df_titanic["Age"]<50)]
len(df1)
# Out:
# 41

# %%
df3 = df_titanic[(df_titanic["Age"]>40) & (df_titanic["Age"]<50)]

# %%
df2 = df_titanic[df_titanic["Age"].between(40,50)]

# %%
df5 = df_titanic[~df_titanic["Age"].between(40,50)]

# %%
df5.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
# 5  14.0      0      0     7538   9.2250   NaN        S

# %%
df4 = df_titanic[df_titanic["Age"].isin([40,46,48,50])]
df4
# Out:
#      PassengerId  Pclass                                               Name  \
# 11           903       1                         Jones, Mr. Charles Cresson
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 25           917       3                            Robins, Mr. Alexander A
# 30           922       2                       Louch, Mr. Charles Alexander
# 139         1031       3                     Goodwin, Mr. Charles Frederick
# 166         1058       1                                 Brandeis, Mr. Emil
# 174         1066       3         Asplund, Mr. Carl Oscar Vilhelm Gustafsson
# 185         1077       2                          Maybery, Mr. Frank Hubert
# 189         1081       2                                    Veal, Mr. James
# 218         1110       1       Widener, Mrs. George Dunton (Eleanor Elkins)
# 239         1131       1        Douglas, Mrs. Walter Donald (Mahala Dutton)
# ...

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df3 = df_titanic[df_titanic["Age"].isin([42,46])]
df3.head()
# Out:
#      PassengerId  Pclass                                               Name  \
# 11           903       1                         Jones, Mr. Charles Cresson
# 128         1020       2                               Bowenur, Mr. Solomon
# 144         1036       1  Lindeberg-Lind, Mr. Erik Gustaf (Mr Edward Lin...
# 158         1050       1                           Borebank, Mr. John James
# 215         1107       1                              Head, Mr. Christopher
#
#       Sex   Age  SibSp  Parch  Ticket   Fare Cabin Embarked
# 11   male  46.0      0      0     694  26.00   NaN        S
# 128  male  42.0      0      0  211535  13.00   NaN        S
# 144  male  42.0      0      0   17475  26.55   NaN        S
# 158  male  42.0      0      0  110489  26.55   D22        S
# 215  male  42.0      0      0  113038  42.50   B11        S

# %%
df3 = df_titanic[~(df_titanic["Age"].isin([42,46]))]
df3.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_titanic.query('Sex == "male" and Age > 50')
# Out:
#      PassengerId  Pclass                             Name   Sex   Age  SibSp  \
# 2            894       2        Myles, Mr. Thomas Francis  male  62.0      0
# 13           905       2             Howard, Mr. Benjamin  male  63.0      1
# 20           912       1           Rothschild, Mr. Martin  male  55.0      1
# 81           973       1               Straus, Mr. Isidor  male  67.0      1
# 131         1023       1        Gracie, Col. Archibald IV  male  53.0      0
# 142         1034       1       Ryerson, Mr. Arthur Larned  male  61.0      1
# 152         1044       3               Storey, Mr. Thomas  male  60.5      0
# 177         1069       1  Stengel, Mr. Charles Emil Henry  male  54.0      1
# 193         1085       2                Lingane, Mr. John  male  61.0      0
# 217         1109       1         Wick, Mr. George Dennick  male  57.0      1
# 236         1128       1         Warren, Mr. Frank Manley  male  64.0      1
# ...

# %%
df_titanic.sort_values(by="Age",ascending = False).head()
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
#
#         Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 96   female  76.0      1      0     19877   78.8500      C46        S
# 81     male  67.0      1      0  PC 17483  221.7792  C55 C57        S
# 236    male  64.0      1      0    110813   75.2500      D37        C
# 305  female  64.0      1      1    112901   26.5500      B26        S
# 179  female  64.0      0      2  PC 17756   83.1583      E45        C

# %%
df_titanic.nlargest(3, 'Age')
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
#
#         Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 96   female  76.0      1      0     19877   78.8500      C46        S
# 81     male  67.0      1      0  PC 17483  221.7792  C55 C57        S
# 179  female  64.0      0      2  PC 17756   83.1583      E45        C

# %%
df_titanic.nlargest(5, 'Fare')
# Out:
#      PassengerId  Pclass                                               Name  \
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 53           945       1                         Fortune, Miss. Ethel Flora
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 59           951       1                        Chaudanson, Miss. Victorine
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked  \
# 343  female  58.0      0      1  PC 17755  512.3292      B51 B53 B55        C
# 53   female  28.0      3      2     19950  263.0000      C23 C25 C27        S
# 69   female  60.0      1      4     19950  263.0000      C23 C25 C27        S
# 24   female  48.0      1      3  PC 17608  262.3750  B57 B59 B63 B66        C
# 59   female  36.0      0      0  PC 17608  262.3750              B61        C
#
# ...

# %%
df_titanic.nsmallest(3, 'Age')
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
# 281         1173       3           Peacock, Master. Alfred Edward    male
#
#       Age  SibSp  Parch              Ticket    Fare Cabin Embarked
# 354  0.17      1      2           C.A. 2315  20.575   NaN        S
# 201  0.33      0      2              347080  14.400   NaN        S
# 281  0.75      1      1  SOTON/O.Q. 3101315  13.775   NaN        S

# %%
df5 = df_titanic

# %%
df5["Check"] = 4.5

# %%
df5
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df5["Check"].unique()
# Out:
# array([4.5])

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Check
# 0  34.5      0      0   330911   7.8292   NaN        Q  True
# 1  47.0      1      0   363272   7.0000   NaN        S  True
# 2  62.0      0      0   240276   9.6875   NaN        Q  True
# 3  27.0      0      0   315154   8.6625   NaN        S  True
# 4  22.0      1      1  3101298  12.2875   NaN        S  True

# %%
df6 = df4.copy()

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Check  length Gender  \
# 0  34.5      0      0   330911   7.8292   NaN        Q    4.5      16      0
# 1  47.0      1      0   363272   7.0000   NaN        S    4.5      32      1
# 2  62.0      0      0   240276   9.6875   NaN        Q    4.5      25      0
# 3  27.0      0      0   315154   8.6625   NaN        S    4.5      16      0
# 4  22.0      1      1  3101298  12.2875   NaN        S    4.5      44      1
#
# ...

# %% [markdown]
# Print only names of first 10 rows
# Print first 10 Name in small case
# Create a new column with name " Small" and have names in small case

# %%
df_titanic["Name"]
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df_titanic["Name"].str.lower()
# Out:
# 0                                  kelly, mr. james
# 1                  wilkes, mrs. james (ellen needs)
# 2                         myles, mr. thomas francis
# 3                                  wirz, mr. albert
# 4      hirvonen, mrs. alexander (helga e lindqvist)
#                            ...
# 413                              spector, mr. woolf
# 414                    oliva y ocana, dona. fermina
# 415                    saether, mr. simon sivertsen
# 416                             ware, mr. frederick
# 417                        peter, master. michael j
# Name: Name, Length: 418, dtype: object

# %%
df5
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df5["Name"] = df_titanic["Name"].str.upper()

# %%
df5
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              KELLY, MR. JAMES
# 1            893       3              WILKES, MRS. JAMES (ELLEN NEEDS)
# 2            894       2                     MYLES, MR. THOMAS FRANCIS
# 3            895       3                              WIRZ, MR. ALBERT
# 4            896       3  HIRVONEN, MRS. ALEXANDER (HELGA E LINDQVIST)
# ..           ...     ...                                           ...
# 413         1305       3                            SPECTOR, MR. WOOLF
# 414         1306       1                  OLIVA Y OCANA, DONA. FERMINA
# 415         1307       3                  SAETHER, MR. SIMON SIVERTSEN
# 416         1308       3                           WARE, MR. FREDERICK
# 417         1309       3                      PETER, MASTER. MICHAEL J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df_titanic["Name"].str.title()
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva Y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df_titanic.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Check', 'length', 'Gender',
#        'Name1', 'Last', 'First'],
#       dtype='object')

# %%
df_titanic.groupby(by = "Sex")["Fare"].mean()
# Out:
# Sex
# female    49.747699
# male      27.527877
# Name: Fare, dtype: float64

# %%
df_titanic.groupby(by = "Sex")["Age"].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Sex
# female  127.0  30.272362  15.428613  0.17  20.5  27.0  38.5  76.0
# male    205.0  30.272732  13.389528  0.33  22.0  27.0  40.0  67.0

# %%
df_titanic.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   418.000000  418.000000  332.000000  418.000000  418.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344
# std     120.810458    0.841838   14.181209    0.896760    0.981429
# min     892.000000    1.000000    0.170000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000
#
#              Fare  Check      length
# count  417.000000  418.0  418.000000
# mean    35.627188    4.5   27.483254
# std     55.907576    0.0    9.971228
# min      0.000000    4.5   13.000000
# 25%      7.895800    4.5   20.000000
# 50%     14.454200    4.5   25.000000
# 75%     31.500000    4.5   30.750000
# max    512.329200    4.5   63.000000

# %% [markdown]
# ## String Methods
#
# We can use the usual string methods to manipulate data inside of a dataframe. To invoke a string method use the .str attribute of a series. Since the only column that is stored as a string is the Name column we will work with that.

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Check
# 0  34.5      0      0   330911   7.8292   NaN        Q  True
# 1  47.0      1      0   363272   7.0000   NaN        S  True
# 2  62.0      0      0   240276   9.6875   NaN        Q  True
# 3  27.0      0      0   315154   8.6625   NaN        S  True
# 4  22.0      1      1  3101298  12.2875   NaN        S  True

# %% [markdown]
# String
# Upper
# Lower
# Title
# Length
# Replace

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Check
# 0  34.5      0      0   330911   7.8292   NaN        Q  True
# 1  47.0      1      0   363272   7.0000   NaN        S  True
# 2  62.0      0      0   240276   9.6875   NaN        Q  True
# 3  27.0      0      0   315154   8.6625   NaN        S  True
# 4  22.0      1      1  3101298  12.2875   NaN        S  True

# %%
df_titanic["length"] = df_titanic["Name"].str.len()
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              KELLY, MR. JAMES    male
# 1          893       3              WILKES, MRS. JAMES (ELLEN NEEDS)  female
# 2          894       2                     MYLES, MR. THOMAS FRANCIS    male
# 3          895       3                              WIRZ, MR. ALBERT    male
# 4          896       3  HIRVONEN, MRS. ALEXANDER (HELGA E LINDQVIST)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Check  length Gender  \
# 0  34.5      0      0   330911   7.8292   NaN        Q    4.5      16      0
# 1  47.0      1      0   363272   7.0000   NaN        S    4.5      32      1
# 2  62.0      0      0   240276   9.6875   NaN        Q    4.5      25      0
# 3  27.0      0      0   315154   8.6625   NaN        S    4.5      16      0
# 4  22.0      1      1  3101298  12.2875   NaN        S    4.5      44      1
#
# ...

# %%
df_male_titanic = df_titanic[df_titanic["Sex"] == "male"]

# %%
#df_male_titanic

# %%
len(df_male_titanic)
# Out:
# 266

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df_male_titanic["Age"],edgecolor = 'black' )
# Out:
# (array([ 8.,  8., 21., 58., 42., 21., 20., 13.,  7.,  7.]),
#  array([ 0.33 ,  6.997, 13.664, 20.331, 26.998, 33.665, 40.332, 46.999,
#         53.666, 60.333, 67.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_male_titanic["Fare"],edgecolor = 'black' )
# Out:
# (array([198.,  33.,  16.,   6.,   0.,   5.,   1.,   0.,   4.,   2.]),
#  array([  0.    ,  26.2375,  52.475 ,  78.7125, 104.95  , 131.1875,
#         157.425 , 183.6625, 209.9   , 236.1375, 262.375 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df_male_titanic["Age"],df_male_titanic["Fare"] )

# %%
df_male_titanic.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             61
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          219
# Embarked         0
# Check            0
# length           0
# Gender           0
# Name1            0
# Last             0
# First            0
# dtype: int64

# %%
len(df_male_titanic)
# Out:
# 266

# %%
df_male_titanic.drop(['Cabin'],axis=1,inplace=True)
# Out:
# D:\Users\Kalyan\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_male_titanic['Fare'].fillna(df_male_titanic['Fare'].mean(),inplace = True)
# Out:
# D:\Users\Kalyan\anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df_male_titanic.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# Age            61
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        0
# Check           0
# length          0
# Gender          0
# Name1           0
# Last            0
# First           0
# dtype: int64

# %%
61/len(df_male_titanic)
# Out:
# 0.22932330827067668

# %%
#df_male_titanic

# %%
len(df_male_titanic)
# Out:
# 266

# %%
#df_male_titanic.dropna(how="any",axis = 0,inplace = True)
df_male_titanic1 = df_male_titanic.dropna(how="any",axis = 0)

# %%
len(df_male_titanic1)
# Out:
# 205

# %%
df_male_titanic1.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Check          0
# length         0
# Gender         0
# Name1          0
# Last           0
# First          0
# dtype: int64

# %%
df_male_titanic1.describe()
# Out:
#        PassengerId     Pclass         Age       SibSp       Parch        Fare  \
# count   205.000000  205.00000  205.000000  205.000000  205.000000  205.000000
# mean   1102.180488    2.22439   30.272732    0.429268    0.292683   31.667777
# std     121.369884    0.81553   13.389528    0.918824    0.774720   45.400837
# min     892.000000    1.00000    0.330000    0.000000    0.000000    0.000000
# 25%     998.000000    2.00000   22.000000    0.000000    0.000000    7.925000
# 50%    1102.000000    2.00000   27.000000    0.000000    0.000000   13.500000
# 75%    1210.000000    3.00000   40.000000    1.000000    0.000000   29.700000
# max    1307.000000    3.00000   67.000000    8.000000    6.000000  262.375000
#
#        Check      length
# count  205.0  205.000000
# mean     4.5   24.429268
# std      0.0    6.197020
# min      4.5   13.000000
# 25%      4.5   20.000000
# 50%      4.5   24.000000
# 75%      4.5   28.000000
# max      4.5   53.000000

# %%
plt.hist(df_male_titanic1["Age"],edgecolor = 'black' )
# Out:
# (array([ 8.,  8., 21., 58., 42., 21., 20., 13.,  7.,  7.]),
#  array([ 0.33 ,  6.997, 13.664, 20.331, 26.998, 33.665, 40.332, 46.999,
#         53.666, 60.333, 67.   ]),
#  <BarContainer object of 10 artists>)

# %%
box_plot_data = [np.array(df_male_titanic1["Age"]), np.array(df_male_titanic1["Fare"])]
box_plot_data
lbl = ['Age','Fare']
plt.figure(figsize=(10,6))
plt.boxplot(box_plot_data, labels=lbl);

# %% [markdown]
# The above bit of code returns the Name column as a str with all lowercase letters. Another useful string method is the contains() method, which returns a boolean if the given string contain the input string.

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Check  length
# 0  34.5      0      0   330911   7.8292   NaN        Q  True      16
# 1  47.0      1      0   363272   7.0000   NaN        S  True      32
# 2  62.0      0      0   240276   9.6875   NaN        Q  True      25
# 3  27.0      0      0   315154   8.6625   NaN        S  True      16
# 4  22.0      1      1  3101298  12.2875   NaN        S  True      44

# %% [markdown]
# ### Can we extract Gender without using "Sex" column??

# %% [markdown]
# Note that we need the escape character "\" to look for the ".".  We can easily the results of the returned series in a new column as follows.

# %% [markdown]
# We can also use these string methods on the column names. Let's say I want to replace all the underscores (there is only one) with blank spaces.  I can do that with the replace method. Recall that I access the column names through the columns attribute of any dataframe.

# %%
df_titanic = pd.read_csv("D:\Kalyan\InnovativeResearchLabs\Batch_Data Analysis_\\Titanic.csv")
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_titanic["Gender"] = df_titanic["Name"].str.contains("Mr\.")
df_titanic["Gender"]
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 413     True
# 414    False
# 415     True
# 416     True
# 417    False
# Name: Gender, Length: 418, dtype: bool

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Check  length
# 0  34.5      0      0   330911   7.8292   NaN        Q  True      16
# 1  47.0      1      0   363272   7.0000   NaN        S  True      32
# 2  62.0      0      0   240276   9.6875   NaN        Q  True      25
# 3  27.0      0      0   315154   8.6625   NaN        S  True      16
# 4  22.0      1      1  3101298  12.2875   NaN        S  True      44

# %% [markdown]
# ### Can we extract Last Name and First Name

# %%
df_titanic["Name1"] = df_titanic["Name"].str.split(",")
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Check  length  Gender  \
# 0  34.5      0      0   330911   7.8292   NaN        Q  True      16    True
# 1  47.0      1      0   363272   7.0000   NaN        S  True      32   False
# 2  62.0      0      0   240276   9.6875   NaN        Q  True      25    True
# 3  27.0      0      0   315154   8.6625   NaN        S  True      16    True
# 4  22.0      1      1  3101298  12.2875   NaN        S  True      44   False
#
# ...

# %%
df_titanic[["Last","First"]]=df_titanic["Name"].str.split(",",expand = True)
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Check  length  Gender  \
# 0  34.5      0      0   330911   7.8292   NaN        Q  True      16    True
# 1  47.0      1      0   363272   7.0000   NaN        S  True      32   False
# 2  62.0      0      0   240276   9.6875   NaN        Q  True      25    True
# 3  27.0      0      0   315154   8.6625   NaN        S  True      16    True
# 4  22.0      1      1  3101298  12.2875   NaN        S  True      44   False
#
# ...

# %% [markdown]
# ###### Set expand  = True

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Check  length  Gender  \
# 0  34.5      0      0   330911   7.8292   NaN        Q  True      16    True
# 1  47.0      1      0   363272   7.0000   NaN        S  True      32   False
# 2  62.0      0      0   240276   9.6875   NaN        Q  True      25    True
# 3  27.0      0      0   315154   8.6625   NaN        S  True      16    True
# 4  22.0      1      1  3101298  12.2875   NaN        S  True      44   False
#
# ...

# %% [markdown]
# ##### Write Dataframe back to excel/csv in local drive

# %%
df_titanic.to_csv("E:\\Innomatics\\data\\new_titanic11.csv")

# %%
df_titanic.to_excel("E:\\Innomatics\\data\\new_titanic12.xlsx")

# %% [markdown]
# ## Map
#
# The map method lets us map values in a column to other values. Let's use map to create a binary column that is 1 for females and 0 for males. We give the mapping that we want by providing the appropriate dictionary

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Check  length  \
# 0  34.5      0      0   330911   7.8292   NaN        Q  True      16
# 1  47.0      1      0   363272   7.0000   NaN        S  True      32
# 2  62.0      0      0   240276   9.6875   NaN        Q  True      25
# 3  27.0      0      0   315154   8.6625   NaN        S  True      16
# 4  22.0      1      1  3101298  12.2875   NaN        S  True      44
#
#                                              Name1
# ...

# %%
df_titanic.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Gender'],
#       dtype='object')

# %%
for i in range(len(df_titanic)) :
    s = df_titanic.loc[i,"Sex"]
    if s == "male":
        df_titanic.loc[i,"Gender"] = 0
    else:
        df_titanic.loc[i,"Gender"] = 1

df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Gender
# 0  34.5      0      0   330911   7.8292   NaN        Q      0
# 1  47.0      1      0   363272   7.0000   NaN        S      1
# 2  62.0      0      0   240276   9.6875   NaN        Q      0
# 3  27.0      0      0   315154   8.6625   NaN        S      0
# 4  22.0      1      1  3101298  12.2875   NaN        S      1

# %%
new = {"male" : 0, "female" : 1}

# %%
df_titanic["gender_Map"] = df_titanic["Sex"].map(new)
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Gender  gender_Map
# 0  34.5      0      0   330911   7.8292   NaN        Q      0           0
# 1  47.0      1      0   363272   7.0000   NaN        S      1           1
# 2  62.0      0      0   240276   9.6875   NaN        Q      0           0
# 3  27.0      0      0   315154   8.6625   NaN        S      0           0
# 4  22.0      1      1  3101298  12.2875   NaN        S      1           1

# %%
def newgender(x):
    if x == "male":
        return 0
    else:
        return 1

# %%
newgender("female")
# Out:
# 1

# %%
for i in range(len(df_titanic)):
    s = df_titanic.loc[i,"Sex"]
    df_titanic.loc[i,"Gender_Function"] = newgender(s)

df_titanic.head()

# %%
df_titanic["Gender_Apply"] = df_titanic["Sex"].apply(newgender)
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Check  length  \
# 0  34.5      0      0   330911   7.8292   NaN        Q  True      16
# 1  47.0      1      0   363272   7.0000   NaN        S  True      32
# 2  62.0      0      0   240276   9.6875   NaN        Q  True      25
# 3  27.0      0      0   315154   8.6625   NaN        S  True      16
# 4  22.0      1      1  3101298  12.2875   NaN        S  True      44
#
#                                              Name1  gender_Map Gender_Apply
# ...

# %%
df_titanic["Gender_lambda"] = df_titanic["Sex"].apply(lambda x: 0 if x=="male" else 1)
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Gender  gender_Map  \
# 0  34.5      0      0   330911   7.8292   NaN        Q      0           0
# 1  47.0      1      0   363272   7.0000   NaN        S      1           1
# 2  62.0      0      0   240276   9.6875   NaN        Q      0           0
# 3  27.0      0      0   315154   8.6625   NaN        S      0           0
# 4  22.0      1      1  3101298  12.2875   NaN        S      1           1
#
#    Gender_lambda
# 0              0
# 1              1
# ...

# %% [markdown]
# Using map

# %% [markdown]
# ## Apply
#
# The apply method applies built-in or custom functions to each row or column of a dataframe. Let's use the apply method to compute the average age and fair. We will need the mean function from numpy to do so.

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Check  length Gender  \
# 0  34.5      0      0   330911   7.8292   NaN        Q  True      16      0
# 1  47.0      1      0   363272   7.0000   NaN        S  True      32      1
# 2  62.0      0      0   240276   9.6875   NaN        Q  True      25      0
# 3  27.0      0      0   315154   8.6625   NaN        S  True      16      0
# 4  22.0      1      1  3101298  12.2875   NaN        S  True      44      1
#
# ...

# %%
#Using apply - axis =0
import numpy as np

df_titanic[["Age"]].apply(np.mean)
# Out:
# Age    30.27259
# dtype: float64

# %%
df_titanic["Age"].mean()

# %% [markdown]
# ## Measure of Central Tendency
# Mathematically central tendency means measuring the center or distribution of location of values of a data set. It gives an idea of the average value of the data in the data set. That in turn helps in evaluating the chances of a new input fitting into the existing data set and hence probability of success.
#
# There are three main measures of central tendency which can be calculated using the methods in pandas python library.
#
# Mean - It is the Average value of the data which is a division of sum of the values with the number of values.
#
# Median - It is the middle value in distribution when the values are arranged in ascending or descending order.
#
# Mode - It is the most commonly occurring value in a distribution

# %%
import pandas as pd

#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','Chanchal','Gasper','Naviya','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])}

#Create a DataFrame
df = pd.DataFrame(d)
print("Mean Values in the Distribution")
print(df.mean())
print("*******************************")
print("Median Values in the Distribution")
print(df.median())
print("*******************************")
print("Mode Values in the Distribution")
print(df["Age"].mode())
# Out:
# Mean Values in the Distribution
# Age       31.833333
# Rating     3.743333
# dtype: float64
# *******************************
# Median Values in the Distribution
# Age       29.50
# Rating     3.79
# dtype: float64
# *******************************
# Mode Values in the Distribution
# 0    23
# 1    25
# 2    30
# dtype: int64

# %%
df.describe()
# Out:
#              Age     Rating
# count  12.000000  12.000000
# mean   31.833333   3.743333
# std     9.232682   0.661628
# min    23.000000   2.560000
# 25%    25.000000   3.230000
# 50%    29.500000   3.790000
# 75%    35.500000   4.132500
# max    51.000000   4.800000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(df['Age'])
# Out:
# D:\Users\Kalyan\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.boxplot(df['Age'], vert = 1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b3d79456a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b3d7945d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b3d7945340>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b3d7952490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b3d79527f0>],
#  'means': []}

# %% [markdown]
# ## Measures of Dispersion

# %% [markdown]
# To understand the data well, only studying measures of central tendency is not enough. One essential measure is how the data is scattered or dispersed. Measures of dispersion indicate how the data is spread or scattered from the measures of central tendency. Measures Of dispersion is also known as “Measures of Variability” because it indicates the variability of the data that how much we still do not know about the data.
#
# In this blog we will discuss about four commonly used measures of dispersion.
#
# - Range
# - Inter-quartile range (IQR)
# - Variance
# - Standard deviation
#
# ### Range
# The simplest measure of dispersion is Range; it is the difference between the highest value and lowest value in the dataset. It offers a crude insight into the spread of the data, but very susceptible to outliers. The range is helpful when you want to focus on extreme values in the dataset.
#
#
# ## Inter-Quartile Range
# The interquartile range is a measure of dispersion, as it also measures the variability of the data, IQR indicates how the data in a series is dispersed from the mean. It measures the difference between the third quartile and the first quartile of the data. It means IQR measure the spread of the middle 50% of the dataset. As the IQR goes up the data points are more spread out and if the IQR is small they assumed to be data is spread around the mean. IQR is also very helpful to determine the outlier in the datasets. To calculate IQR first we have to sort the data in ascending order.
#
# The Formula of IQR is:
#
# IQR = Third Quartile – First Quartile
#
#
# ### Variance
# Variance is one of the important measures of dispersion, Variance measure the variability of the data around its mean or average. In other words, variance indicates how the data is deviated or dispersed from its mean or average. High variance means there is more variability or we can say that the data deviates more from its mean whereas low variance means there is less variability. If the variance is zero that means all the values in the data are identical. Variance can never be negative. It is denoted by (sigma square).

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Standard Deviation
# Standard deviation is an important measure of dispersion and frequently used in statistics. Standard deviation is simply the square root of variance. It indicates how far away the dispersion of the dataset from its mean. It is denoted by (sigma). Simply standard deviation helps us to find the spread of the data about its mean or average. A low Standard deviation indicates that the data are less spread from their average where a high standard deviation indicates the data are more spread out from its average.
#
# The formula of standard deviation for population:

# %% [markdown]
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Outler_Calculation.png](attachment:Outler_Calculation.png)

# %%
tips = pd.read_csv(r'D:\Kalyan\InnovativeResearchLabs\Batch_Data Analysis_\07. Visuallization Basics - Matplotlib and Seaborn\data//tips.csv')

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(data = tips, x='day', y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
