# %%
import pandas as pd

# %%
df=pd.read_excel(r"D:\Kalyan\InnovativeResearchLabs\Batch_Data Analysis_\\loandata.xlsx")

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# 2             NaN         Urban           N
# 3             1.0         Rural           Y
# 4             1.0         Rural           Y

# %%
path+filename+extension
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-beb9ea3c2c8d> in <module>
# ----> 1 path+filename+extension
#
# NameError: name 'path' is not defined

# %% [markdown]
# # Indexing, Selecting and Slicing Data in Pandas
#
# # Position and Label Based Indexing: ```df.iloc``` and ```df.loc```
#
# You have seen some ways of selecting rows and columns from dataframes. Let's now see some other ways of indexing dataframes, which pandas recommends, since they are more explicit (and less ambiguous).
#
# There are two main ways of indexing dataframes:
# 1. Position based indexing using ```df.iloc```
# 2. Label based indexing using ```df.loc```
#
# Using both the methods, we will do the following indexing operations on a dataframe:
# * Selecting single elements/cells
# * Selecting single and multiple rows
# * Selecting single and multiple columns
# * Selecting multiple rows and columns
#
#
# Pandas now supports three types of Multi-axes indexing:
#
# **.loc()**\
# Pandas provide various methods to have purely label based indexing. When slicing, the start bound is also included. Integers are valid labels, but they refer to the label and not the position.
#
# **.iloc()**\
# Pandas provide various methods in order to get purely integer based indexing. Like python and numpy, these are 0-based indexing.
#
# **.ix()**\
# Besides pure label based and integer based, Pandas provides a hybrid method for selections and subsetting the object using the .ix() operator.

# %% [markdown]
# ## Slicing/indexing
#
# ### iloc - index location, whish used to retrieve the data if the index is in numbers
# ### loc - location, whish used to retrieve the data if the index is in String/character

# %%
df.head()

# %%
df.iloc[0,0]

# %%
df.iloc[0,1]

# %%
df.iloc[2,3]

# %%
df.loc[2,"Gender"]

# %%
df.iloc[0:3,]

# %%
df.loc[0:3,]

# %%
df.iloc[0:3,1:3]

# %%
df.loc[0:3,["Gender","Married"]]

# %%
df.head()

# %%
df.loc[ 0:3, "Loan_ID":"ApplicantIncome"]

# %%
df.loc[ 0:3, ["Loan_ID","ApplicantIncome","CoapplicantIncome"]]

# %%
df.iloc[: , [0,6,7]]

# %%
df[["Loan_ID","ApplicantIncome","CoapplicantIncome"]]

# %%
df.iloc[1:3,1:3]

# %%
df.loc[0:2,"Gender"]

# %%
df.loc[0:2,["Gender","Married"]]

# %%
df.head()

# %%
# row selection
df.iloc[[3,6]]

# %%
df.iloc[2:4]

# %%
## multiple columns

df3 = df[['Gender','Married']]

# %%
df3.head()

# %%
df3["Gender"][0] = "Female"

# %%
df3.iloc[1,0] = "Male"

# %%
df3

# %%
df3

# %%
df

# %%
li[0] == "Male"

# %%
df["Gender"]

# %%
df["Gender"] == "Male"

# %%
df3 = df.loc[df["Gender"] == "Male"]
df3.head()

# %%
df3 = df.loc[df["Gender"] == "Male",["Loan_ID","Gender"]]
df3

# %%
df.loc[(df["ApplicantIncome"]<1500) &  (df["CoapplicantIncome"]> 3000)]

# %%
(df["Gender"] == "Male") &  (df["ApplicantIncome"]<1500)

# %%
df6 = df.loc[(df["Gender"] == "Female") &  (df["ApplicantIncome"]>1500)]

# %%
df6

# %% [markdown]
# ### How many people are married and have asked for loanAmount more than 500 ??

# %%
(df["Married"] == "Yes") &  (df["LoanAmount"]>500)

# %%
df4 = df.loc[(df["Married"] == "Yes") &  (df["LoanAmount"]>500)]
len(df4)

# %% [markdown]
# ### How many people are married or have asked for loanAmount more than 500 ??

# %%
df4 = df.loc[(df["Married"] == "Yes") |  (df["LoanAmount"]>500)]
len(df4)

# %%
df3["Gender"].unique()

# %%
df3["Gender"].value_counts()

# %%
df2 = df.loc[df["Gender"] == "Male"]
df2.tail()

# %%
df2 = df.loc[df["Gender"] == "Male"  ,  ["Gender","Married","Dependents"]]
df2.tail()

# %%
df_male = df.loc[df["Gender"]=="Male"]
df_male.head()

# %%
df3 = df.loc[(df["Gender"]=="Male") & (df["ApplicantIncome"]>10000)]
df3.head()

# %%
df4 = df.loc[(df["Gender"]=="Male") & (df["ApplicantIncome"]>10000),["Gender","LoanAmount"]]
df4.head()

# %% [markdown]
# ==  ,!=  >  <
#
# And  &
# Or   |
#
# The 'AND' operator is represented by a & (Note that 'and' doesn't work with pandas)
#  E.g. all applicants whose Gender is Male  and  Married is Yes
# The 'OR' operator is represented by a | (Note that 'or' doesn't work with pandas)

# %% [markdown]
# ### Derived Variables

# %% [markdown]
# Years of Loan Term

# %%
df.head()

# %%
df["loan_years"] = df["Loan_Amount_Term"]/12
df.head()

# %%
df["totalincome"] = df["ApplicantIncome"] + df["CoapplicantIncome"]
df.head()

# %% [markdown]
# Total Income Supporting Applicant

# %%
type(df["ApplicantIncome"])
# Out:
# pandas.core.series.Series

# %%
# You can extract the values of a dataframe as a numpy array using df.values 

income_array=df["ApplicantIncome"].values

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
Education_array = df["Education"].values

# %%
print(type(Education_array))
# Out:
# <class 'numpy.ndarray'>

# %%
len(Education_array)
# Out:
# 614

# %%
income_array
# Out:
# array([  150,   210,   416,   645,   674,  1000,  1025,  1025,  1299,
#         1378,  1442,  1500,  1538,  1600,  1625,  1668,  1759,  1782,
#         1800,  1800,  1809,  1811,  1820,  1820,  1828,  1830,  1836,
#         1853,  1863,  1875,  1880,  1907,  1916,  1926,  1928,  1958,
#         1958,  1963,  1977,  1993,  2000,  2014,  2014,  2031,  2045,
#         2058,  2060,  2071,  2083,  2083,  2130,  2132,  2137,  2138,
#         2149,  2165,  2167,  2178,  2192,  2213,  2213,  2214,  2221,
#         2237,  2239,  2253,  2275,  2281,  2297,  2301,  2309,  2330,
#         2333,  2333,  2333,  2346,  2366,  2378,  2378,  2383,  2383,
#         5468,  5488,  5500,  5500,  5503,  5516,  5532,  5568,  5649,
#         5667,  5677,  5695,  5703,  5703,  5708,  5726,  5746,  5746,
#         5780,  5800,  5815,  5818,  5819,  5821,  5829,  5849,  5923,
#         5935,  5941,  5955,  6000,  6000,  6000,  6000,  6000,  6000,
#         6033,  6045,  6050,  6065,  6080,  6083,  6096,  6125,  6133,
#         6216,  6250,  6250,  6250,  6250,  6256,  6277,  6283,  6325,
#         6333,  6383,  6400,  6400,  6406,  6417,  6500,  6540,  6608,
#         6633,  6700,  6782,  6783,  6822,  6875,  6950,  7085,  7100,
#         7142,  7167,  7200,  7250,  7333,  7333,  7441,  7451,  7578,
#         7583,  7660,  7667,  7740,  7787,  7901,  7933,  7948,  8000,
#         8072,  8080,  8300,  8333,  8333,  8333,  8333,  8334,  8566,
#         8624,  8666,  8750,  8750,  8799,  9083,  9166,  9167,  9323,
#         9323,  9328,  9357,  9504,  9508,  9538,  9560,  9703,  9833,
#         9963, 10000, 10000, 10000, 10047, 10139, 10408, 10416, 10513,
#        10750, 10833, 11000, 11146, 11250, 11417, 11500, 11757, 12000,
#        12000, 12500, 12841, 12876, 13262, 13650, 14583, 14583, 14683,
#        14866, 14880, 14999, 15000, 15759, 16120, 16250, 16525, 16666,
#        16667, 16692, 17263, 17500, 18165, 18333, 19484, 19730, 20166,
#        20233, 20667, 20833, 23803, 33846, 37719, 39147, 39999, 51763,
#        63337, 81000], dtype=int64)

# %%
len(income_array)
# Out:
# 614

# %%
type(income_array)
# Out:
# numpy.ndarray

# %% [markdown]
# DataFrame.to_numpy() does not include the index or column labels in the output.

# %%
income_array1=df["ApplicantIncome"].to_numpy()

# %%
type(income_array1)
# Out:
# numpy.ndarray

# %%
income_array1
# Out:
# array([  150,   210,   416,   645,   674,  1000,  1025,  1025,  1299,
#         1378,  1442,  1500,  1538,  1600,  1625,  1668,  1759,  1782,
#         1800,  1800,  1809,  1811,  1820,  1820,  1828,  1830,  1836,
#         1853,  1863,  1875,  1880,  1907,  1916,  1926,  1928,  1958,
#         1958,  1963,  1977,  1993,  2000,  2014,  2014,  2031,  2045,
#         2058,  2060,  2071,  2083,  2083,  2130,  2132,  2137,  2138,
#         2149,  2165,  2167,  2178,  2192,  2213,  2213,  2214,  2221,
#         2237,  2239,  2253,  2275,  2281,  2297,  2301,  2309,  2330,
#         2333,  2333,  2333,  2346,  2366,  2378,  2378,  2383,  2383,
#         2395,  2400,  2400,  2400,  2400,  2423,  2425,  2435,  2439,
#         2454,  2473,  2479,  2479,  2483,  2484,  2491,  2492,  2499,
#         2500,  2500,  2500,  2500,  2500,  2500,  2500,  2500,  2500,
#         2507,  2510,  2526,  2550,  2577,  2583,  2583,  2583,  2583,
#         2600,  2600,  2600,  2600,  2600,  2600,  2609,  2620,  2625,
#         2645,  2647,  2653,  2661,  2666,  2666,  2667,  2679,  2698,
#         2699,  2708,  2717,  2718,  2720,  2726,  2750,  2755,  2764,
#         2768,  2769,  2785,  2787,  2799,  2833,  2833,  2873,  2875,
#         7142,  7167,  7200,  7250,  7333,  7333,  7441,  7451,  7578,
#         7583,  7660,  7667,  7740,  7787,  7901,  7933,  7948,  8000,
#         8072,  8080,  8300,  8333,  8333,  8333,  8333,  8334,  8566,
#         8624,  8666,  8750,  8750,  8799,  9083,  9166,  9167,  9323,
#         9323,  9328,  9357,  9504,  9508,  9538,  9560,  9703,  9833,
#         9963, 10000, 10000, 10000, 10047, 10139, 10408, 10416, 10513,
#        10750, 10833, 11000, 11146, 11250, 11417, 11500, 11757, 12000,
#        12000, 12500, 12841, 12876, 13262, 13650, 14583, 14583, 14683,
#        14866, 14880, 14999, 15000, 15759, 16120, 16250, 16525, 16666,
#        16667, 16692, 17263, 17500, 18165, 18333, 19484, 19730, 20166,
#        20233, 20667, 20833, 23803, 33846, 37719, 39147, 39999, 51763,
#        63337, 81000], dtype=int64)

# %%
income_list=list(df["ApplicantIncome"])
type(income_list)
# Out:
# list

# %%
income_list1=df["ApplicantIncome"].tolist()
type(income_list1)
# Out:
# list

# %%
df["ApplicantIncome"]
# Out:
# 0        150
# 1        210
# 2        416
# 3        645
# 4        674
#        ...
# 609    39147
# 610    39999
# 611    51763
# 612    63337
# 613    81000
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
df[["ApplicantIncome"]]
# Out:
#      ApplicantIncome
# 0                150
# 1                210
# 2                416
# 3                645
# 4                674
# ..               ...
# 609            39147
# 610            39999
# 611            51763
# 612            63337
# 613            81000
#
# [614 rows x 1 columns]

# %%
df.head()

# %%
##### Sort by Applicant Income
df4 = df.sort_values(by='CoapplicantIncome')
df4.head()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 306  LP001790  Female      No          1      Graduate            No
# 400  LP002161  Female      No          1      Graduate            No
# 397  LP001136    Male     Yes          0  Not Graduate           Yes
# 396  LP001097    Male      No          1      Graduate           Yes
# 395  LP002519    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 306             3812                0.0       112.0             360.0
# 400             4723                0.0        81.0             360.0
# 397             4695                0.0        96.0               NaN
# 396             4692                0.0       106.0             360.0
# 395             4691                0.0       100.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 306             1.0         Rural           Y
# 400             1.0     Semiurban           N
# 397             1.0         Urban           Y
# 396             1.0         Rural           N
# 395             1.0     Semiurban           Y

# %%
##### Sort by Applicant Income
df4 = df.sort_values(by='CoapplicantIncome',ascending=False)
df4.head()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 2    LP002949  Female      No         3+  Graduate           NaN
# 26   LP002893    Male      No          0  Graduate            No
# 105  LP002297    Male      No          0  Graduate            No
# 13   LP002342    Male     Yes          2  Graduate           Yes
# 446  LP001610    Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 2                416            41667.0       350.0             180.0
# 26              1836            33837.0        90.0             360.0
# 105             2500            20000.0       103.0             360.0
# 13              1600            20000.0       239.0             360.0
# 446             5516            11300.0       495.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 2               NaN         Urban           N
# 26              1.0         Urban           N
# 105             1.0     Semiurban           Y
# 13              1.0         Urban           N
# 446             0.0     Semiurban           N

# %%
### Column Rename
df=df.rename(columns={'ApplicantIncome':'Income'})
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  Income  \
# 0  LP001722    Male     Yes          0      Graduate            No     150
# 1  LP002502  Female     Yes          2  Not Graduate           NaN     210
# 2  LP002949  Female      No         3+      Graduate           NaN     416
# 3  LP002603  Female      No          0      Graduate            No     645
# 4  LP001644     NaN     Yes          0      Graduate           Yes     674
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0             1800.0       135.0             360.0             1.0
# 1             2917.0        98.0             360.0             1.0
# 2            41667.0       350.0             180.0             NaN
# 3             3683.0       113.0             480.0             1.0
# 4             5296.0       168.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Rural           N
# 1     Semiurban           Y
# 2         Urban           N
# 3         Rural           Y
# 4         Rural           Y

# %% [markdown]
# axis=0  rows
# axis=1  columns

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# 2             NaN         Urban           N
# 3             1.0         Rural           Y
# 4             1.0         Rural           Y

# %%
df4 = df.drop(columns=['Gender', 'Married'])
df4.head()
# Out:
#     Loan_ID Dependents     Education Self_Employed  ApplicantIncome  \
# 0  LP001722          0      Graduate            No              150
# 1  LP002502          2  Not Graduate           NaN              210
# 2  LP002949         3+      Graduate           NaN              416
# 3  LP002603          0      Graduate            No              645
# 4  LP001644          0      Graduate           Yes              674
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0             1800.0       135.0             360.0             1.0
# 1             2917.0        98.0             360.0             1.0
# 2            41667.0       350.0             180.0             NaN
# 3             3683.0       113.0             480.0             1.0
# 4             5296.0       168.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Rural           N
# 1     Semiurban           Y
# 2         Urban           N
# 3         Rural           Y
# 4         Rural           Y

# %%
#Delete rows with index 0 and 2
drop_rows = df.drop([0,2], inplace = False, axis=0)
drop_rows.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  Income  \
# 1  LP002502  Female     Yes          2  Not Graduate           NaN     210
# 3  LP002603  Female      No          0      Graduate            No     645
# 4  LP001644     NaN     Yes          0      Graduate           Yes     674
# 5  LP001259    Male     Yes          1      Graduate           Yes    1000
# 6  LP002345    Male     Yes          0      Graduate            No    1025
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             2917.0        98.0             360.0             1.0
# 3             3683.0       113.0             480.0             1.0
# 4             5296.0       168.0             360.0             1.0
# 5             3022.0       110.0             360.0             1.0
# 6             2773.0       112.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1     Semiurban           Y
# 3         Rural           Y
# 4         Rural           Y
# 5         Urban           N
# 6         Rural           Y

# %%
drop_rows.drop([3,4], inplace = True, axis=0)

# %%
drop_rows
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  Income  \
# 1    LP002502  Female     Yes          2  Not Graduate           NaN     210
# 5    LP001259    Male     Yes          1      Graduate           Yes    1000
# 6    LP002345    Male     Yes          0      Graduate            No    1025
# 7    LP002717    Male     Yes          0      Graduate            No    1025
# 8    LP001030    Male     Yes          2      Graduate            No    1299
# ..        ...     ...     ...        ...           ...           ...     ...
# 609  LP001640    Male     Yes          0      Graduate           Yes   39147
# 610  LP001536    Male     Yes         3+      Graduate            No   39999
# 611  LP001585     NaN     Yes         3+      Graduate            No   51763
# 612  LP002101    Male     Yes          0      Graduate           NaN   63337
# 613  LP002317    Male     Yes         3+      Graduate            No   81000
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               2917.0        98.0             360.0             1.0
# 5               3022.0       110.0             360.0             1.0
# 6               2773.0       112.0             360.0             1.0
# 7               5500.0       216.0             360.0             NaN
# 8               1086.0        17.0             120.0             1.0
# ..                 ...         ...               ...             ...
# 609             4750.0       120.0             360.0             1.0
# 610                0.0       600.0             180.0             0.0
# 611                0.0       700.0             300.0             1.0
# 612                0.0       490.0             180.0             1.0
# 613                0.0       360.0             360.0             0.0
#
#     Property_Area Loan_Status
# 1       Semiurban           Y
# 5           Urban           N
# 6           Rural           Y
# 7           Rural           Y
# 8           Urban           Y
# ..            ...         ...
# 609     Semiurban           Y
# 610     Semiurban           Y
# 611         Urban           Y
# 612         Urban           Y
# 613         Rural           N
#
# [610 rows x 13 columns]

# %%
drop_rows.drop([5,6], inplace = False, axis=0)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  Income  \
# 1    LP002502  Female     Yes          2  Not Graduate           NaN     210
# 7    LP002717    Male     Yes          0      Graduate            No    1025
# 8    LP001030    Male     Yes          2      Graduate            No    1299
# 9    LP001267  Female     Yes          2      Graduate            No    1378
# 10   LP001086    Male      No          0  Not Graduate            No    1442
# ..        ...     ...     ...        ...           ...           ...     ...
# 609  LP001640    Male     Yes          0      Graduate           Yes   39147
# 610  LP001536    Male     Yes         3+      Graduate            No   39999
# 611  LP001585     NaN     Yes         3+      Graduate            No   51763
# 612  LP002101    Male     Yes          0      Graduate           NaN   63337
# 613  LP002317    Male     Yes         3+      Graduate            No   81000
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               2917.0        98.0             360.0             1.0
# 7               5500.0       216.0             360.0             NaN
# 8               1086.0        17.0             120.0             1.0
# 9               1881.0       167.0             360.0             1.0
# 10                 0.0        35.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609             4750.0       120.0             360.0             1.0
# 610                0.0       600.0             180.0             0.0
# 611                0.0       700.0             300.0             1.0
# 612                0.0       490.0             180.0             1.0
# 613                0.0       360.0             360.0             0.0
#
#     Property_Area Loan_Status
# 1       Semiurban           Y
# 7           Rural           Y
# 8           Urban           Y
# 9           Urban           N
# 10          Urban           N
# ..            ...         ...
# 609     Semiurban           Y
# 610     Semiurban           Y
# 611         Urban           Y
# 612         Urban           Y
# 613         Rural           N
#
# [608 rows x 13 columns]

# %%
drop_rows
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  Income  \
# 1    LP002502  Female     Yes          2  Not Graduate           NaN     210
# 5    LP001259    Male     Yes          1      Graduate           Yes    1000
# 6    LP002345    Male     Yes          0      Graduate            No    1025
# 7    LP002717    Male     Yes          0      Graduate            No    1025
# 8    LP001030    Male     Yes          2      Graduate            No    1299
# ..        ...     ...     ...        ...           ...           ...     ...
# 609  LP001640    Male     Yes          0      Graduate           Yes   39147
# 610  LP001536    Male     Yes         3+      Graduate            No   39999
# 611  LP001585     NaN     Yes         3+      Graduate            No   51763
# 612  LP002101    Male     Yes          0      Graduate           NaN   63337
# 613  LP002317    Male     Yes         3+      Graduate            No   81000
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               2917.0        98.0             360.0             1.0
# 5               3022.0       110.0             360.0             1.0
# 6               2773.0       112.0             360.0             1.0
# 7               5500.0       216.0             360.0             NaN
# 8               1086.0        17.0             120.0             1.0
# ..                 ...         ...               ...             ...
# 609             4750.0       120.0             360.0             1.0
# 610                0.0       600.0             180.0             0.0
# 611                0.0       700.0             300.0             1.0
# 612                0.0       490.0             180.0             1.0
# 613                0.0       360.0             360.0             0.0
#
#     Property_Area Loan_Status
# 1       Semiurban           Y
# 5           Urban           N
# 6           Rural           Y
# 7           Rural           Y
# 8           Urban           Y
# ..            ...         ...
# 609     Semiurban           Y
# 610     Semiurban           Y
# 611         Urban           Y
# 612         Urban           Y
# 613         Rural           N
#
# [610 rows x 13 columns]

# %%
df2=df.copy()

# %%
df2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150             1800.0       135.0             360.0
# 1                210             2917.0        98.0             360.0
# 2                416            41667.0       350.0             180.0
# 3                645             3683.0       113.0             480.0
# 4                674             5296.0       168.0             360.0
# ..               ...                ...         ...               ...
# 609            39147             4750.0       120.0             360.0
# 610            39999                0.0       600.0             180.0
# 611            51763                0.0       700.0             300.0
# 612            63337                0.0       490.0             180.0
# 613            81000                0.0       360.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Rural           N
# 1               1.0     Semiurban           Y
# 2               NaN         Urban           N
# 3               1.0         Rural           Y
# 4               1.0         Rural           Y
# ..              ...           ...         ...
# 609             1.0     Semiurban           Y
# 610             0.0     Semiurban           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0         Rural           N
#
# [614 rows x 13 columns]

# %%
df2.drop('ApplicantIncome',axis = 1)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0               1800.0       135.0             360.0             1.0
# 1               2917.0        98.0             360.0             1.0
# 2              41667.0       350.0             180.0             NaN
# 3               3683.0       113.0             480.0             1.0
# 4               5296.0       168.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609             4750.0       120.0             360.0             1.0
# 610                0.0       600.0             180.0             0.0
# 611                0.0       700.0             300.0             1.0
# 612                0.0       490.0             180.0             1.0
# 613                0.0       360.0             360.0             0.0
#
#     Property_Area Loan_Status
# 0           Rural           N
# 1       Semiurban           Y
# 2           Urban           N
# 3           Rural           Y
# 4           Rural           Y
# ..            ...         ...
# 609     Semiurban           Y
# 610     Semiurban           Y
# 611         Urban           Y
# 612         Urban           Y
# 613         Rural           N
#
# [614 rows x 12 columns]

# %%
df2.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# 2             NaN         Urban           N
# 3             1.0         Rural           Y
# 4             1.0         Rural           Y

# %%
# Dropping
#### axis = 0 indicates rows
#### axis = 1 indicates columns

df1 = df2.drop('Income',axis = 1)
df1

# %%
df2.drop('Income',axis = 1, inplace = True)

# %%
df2.head()

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Income', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.columns[[0,1,3]]
# Out:
# Index(['Loan_ID', 'Gender', 'Dependents'], dtype='object')

# %%
#Delete first, second and fourth columns:

df2.drop(df.columns[[0,1,3]], axis=1, inplace=True)
df2.head()
# Out:
#   Married     Education Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 0     Yes      Graduate            No              150             1800.0
# 1     Yes  Not Graduate           NaN              210             2917.0
# 2      No      Graduate           NaN              416            41667.0
# 3      No      Graduate            No              645             3683.0
# 4     Yes      Graduate           Yes              674             5296.0
#
#    LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status
# 0       135.0             360.0             1.0         Rural           N
# 1        98.0             360.0             1.0     Semiurban           Y
# 2       350.0             180.0             NaN         Urban           N
# 3       113.0             480.0             1.0         Rural           Y
# 4       168.0             360.0             1.0         Rural           Y

# %%
#### Alternative without Dropping ??

df_not_male = df.loc[df["Gender"]!="Male"]
df_not_male.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  Income  \
# 1  LP002502  Female     Yes          2  Not Graduate           NaN     210
# 2  LP002949  Female      No         3+      Graduate           NaN     416
# 3  LP002603  Female      No          0      Graduate            No     645
# 4  LP001644     NaN     Yes          0      Graduate           Yes     674
# 9  LP001267  Female     Yes          2      Graduate            No    1378
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             2917.0        98.0             360.0             1.0
# 2            41667.0       350.0             180.0             NaN
# 3             3683.0       113.0             480.0             1.0
# 4             5296.0       168.0             360.0             1.0
# 9             1881.0       167.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1     Semiurban           Y
# 2         Urban           N
# 3         Rural           Y
# 4         Rural           Y
# 9         Urban           N

# %%
df5=df['ApplicantIncome']

# %%
# Notice that, the resultant is a Series object
print(type(df5))

# %%
df6=df[['ApplicantIncome']]

# %%
type(df6)
