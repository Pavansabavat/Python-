# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\DELL\DATA SCIENCE\DATA ANALYSIS CLASS NOTES\titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["Age"]>40
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: Age, Length: 418, dtype: bool

# %%
df1=df[df["Age"]>40]
df1.head()
# Out:
#     PassengerId  Pclass                                               Name  \
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 11          903       1                         Jones, Mr. Charles Cresson
# 13          905       2                               Howard, Mr. Benjamin
# 14          906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
#
#        Sex   Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# 1   female  47.0      1      0       363272   7.0000   NaN        S
# 2     male  62.0      0      0       240276   9.6875   NaN        Q
# 11    male  46.0      0      0          694  26.0000   NaN        S
# 13    male  63.0      1      0        24065  26.0000   NaN        S
# 14  female  47.0      1      0  W.E.P. 5734  61.1750   E31        S

# %%
df2=df[(df['Age']>=40) & (df['Age']<=50 )]
df2.head()
# Out:
#     PassengerId  Pclass                                               Name  \
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 11          903       1                         Jones, Mr. Charles Cresson
# 14          906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 19          911       3              Assaf Khalil, Mrs. Mariana (Miriam")"
# 24          916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
#
#        Sex   Age  SibSp  Parch       Ticket     Fare            Cabin Embarked
# 1   female  47.0      1      0       363272    7.000              NaN        S
# 11    male  46.0      0      0          694   26.000              NaN        S
# 14  female  47.0      1      0  W.E.P. 5734   61.175              E31        S
# 19  female  45.0      0      0         2696    7.225              NaN        C
# 24  female  48.0      1      3     PC 17608  262.375  B57 B59 B63 B66        C

# %%
len(df2)
# Out:
# 51

# %% [markdown]
# ## another method

# %%
df2=df[df["Age"].between(40,50)]
# df2=df[(df['Age']>40) & (df['Age']<50 )]   codes are same to get the o/ps

# %%
df2.head()
# Out:
#     PassengerId  Pclass                                               Name  \
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 11          903       1                         Jones, Mr. Charles Cresson
# 14          906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 19          911       3              Assaf Khalil, Mrs. Mariana (Miriam")"
# 24          916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
#
#        Sex   Age  SibSp  Parch       Ticket     Fare            Cabin Embarked
# 1   female  47.0      1      0       363272    7.000              NaN        S
# 11    male  46.0      0      0          694   26.000              NaN        S
# 14  female  47.0      1      0  W.E.P. 5734   61.175              E31        S
# 19  female  45.0      0      0         2696    7.225              NaN        C
# 24  female  48.0      1      3     PC 17608  262.375  B57 B59 B63 B66        C

# %%
len(df2)
# Out:
# 51

# %%
df2=df[df["Age"].isin([40,46,48,50])]
df2.head()
# Out:
#      PassengerId  Pclass                                             Name  \
# 11           903       1                       Jones, Mr. Charles Cresson
# 24           916       1  Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 25           917       3                          Robins, Mr. Alexander A
# 30           922       2                     Louch, Mr. Charles Alexander
# 139         1031       3                   Goodwin, Mr. Charles Frederick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare            Cabin Embarked
# 11     male  46.0      0      0         694   26.000              NaN        S
# 24   female  48.0      1      3    PC 17608  262.375  B57 B59 B63 B66        C
# 25     male  50.0      1      0   A/5. 3337   14.500              NaN        S
# 30     male  50.0      1      0  SC/AH 3085   26.000              NaN        S
# 139    male  40.0      1      6     CA 2144   46.900              NaN        S

# %% [markdown]
# ## ~  it is  totall reverse

# %%
df3=df[~(df["Age"].isin([42,45]))]

# %%
df3.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
len(df3)
# Out:
# 404

# %%
df4=df[~(df["Age"].isin([42,45,46,48]))]
df4.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ## query

# %%
df.query('Sex=="male" and Age>50')
# Out:
#      PassengerId  Pclass                             Name   Sex   Age  SibSp  \
# 2            894       2        Myles, Mr. Thomas Francis  male  62.0      0
# 13           905       2             Howard, Mr. Benjamin  male  63.0      1
# 20           912       1           Rothschild, Mr. Martin  male  55.0      1
# 81           973       1               Straus, Mr. Isidor  male  67.0      1
# 131         1023       1        Gracie, Col. Archibald IV  male  53.0      0
# 142         1034       1       Ryerson, Mr. Arthur Larned  male  61.0      1
# 152         1044       3               Storey, Mr. Thomas  male  60.5      0
# 177         1069       1  Stengel, Mr. Charles Emil Henry  male  54.0      1
# 193         1085       2                Lingane, Mr. John  male  61.0      0
# 217         1109       1         Wick, Mr. George Dennick  male  57.0      1
# 236         1128       1         Warren, Mr. Frank Manley  male  64.0      1
# ...

# %%
df.sort_values(by='Age',ascending=False).head()
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
#
#         Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 96   female  76.0      1      0     19877   78.8500      C46        S
# 81     male  67.0      1      0  PC 17483  221.7792  C55 C57        S
# 236    male  64.0      1      0    110813   75.2500      D37        C
# 305  female  64.0      1      1    112901   26.5500      B26        S
# 179  female  64.0      0      2  PC 17756   83.1583      E45        C

# %%
df.nlargest(5,"Age")
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
#
#         Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 96   female  76.0      1      0     19877   78.8500      C46        S
# 81     male  67.0      1      0  PC 17483  221.7792  C55 C57        S
# 179  female  64.0      0      2  PC 17756   83.1583      E45        C
# 236    male  64.0      1      0    110813   75.2500      D37        C
# 305  female  64.0      1      1    112901   26.5500      B26        S

# %%
df.nlargest(5,"Fare")
# Out:
#      PassengerId  Pclass                                               Name  \
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 53           945       1                         Fortune, Miss. Ethel Flora
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 59           951       1                        Chaudanson, Miss. Victorine
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 343  female  58.0      0      1  PC 17755  512.3292      B51 B53 B55        C
# 53   female  28.0      3      2     19950  263.0000      C23 C25 C27        S
# 69   female  60.0      1      4     19950  263.0000      C23 C25 C27        S
# 24   female  48.0      1      3  PC 17608  262.3750  B57 B59 B63 B66        C
# 59   female  36.0      0      0  PC 17608  262.3750              B61        C

# %%
df.nsmallest(5,"Age")
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
# 281         1173       3           Peacock, Master. Alfred Edward    male
# 307         1199       3                Aks, Master. Philip Frank    male
# 250         1142       2                    West, Miss. Barbara J  female
#
#       Age  SibSp  Parch              Ticket    Fare Cabin Embarked
# 354  0.17      1      2           C.A. 2315  20.575   NaN        S
# 201  0.33      0      2              347080  14.400   NaN        S
# 281  0.75      1      1  SOTON/O.Q. 3101315  13.775   NaN        S
# 307  0.83      0      1              392091   9.350   NaN        S
# 250  0.92      1      2          C.A. 34651  27.750   NaN        S

# %%
df.nsmallest(5,"Fare")
# Out:
#      PassengerId  Pclass                                   Name   Sex   Age  \
# 266         1158       1  Chisholm, Mr. Roderick Robert Crispin  male   NaN
# 372         1264       1                Ismay, Mr. Joseph Bruce  male  49.0
# 21           913       3              Olsen, Master. Artur Karl  male   9.0
# 116         1008       3                       Thomas, Mr. John  male   NaN
# 133         1025       3                  Thomas, Mr. Charles P  male   NaN
#
#      SibSp  Parch   Ticket    Fare        Cabin Embarked
# 266      0      0   112051  0.0000          NaN        S
# 372      0      0   112058  0.0000  B52 B54 B56        S
# 21       0      1  C 17368  3.1708          NaN        S
# 116      0      0     2681  6.4375          NaN        C
# 133      1      0     2621  6.4375          NaN        C

# %%
df5=df

# %%
df5['check']="True"
df5.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked check
# 0  34.5      0      0   330911   7.8292   NaN        Q  True
# 1  47.0      1      0   363272   7.0000   NaN        S  True
# 2  62.0      0      0   240276   9.6875   NaN        Q  True
# 3  27.0      0      0   315154   8.6625   NaN        S  True
# 4  22.0      1      1  3101298  12.2875   NaN        S  True

# %%
df5['check']=4.3
df5.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  check
# 0  34.5      0      0   330911   7.8292   NaN        Q    4.3
# 1  47.0      1      0   363272   7.0000   NaN        S    4.3
# 2  62.0      0      0   240276   9.6875   NaN        Q    4.3
# 3  27.0      0      0   315154   8.6625   NaN        S    4.3
# 4  22.0      1      1  3101298  12.2875   NaN        S    4.3

# %%
df5['check'].unique()
# Out:
# array([4.3])

# %%
df["Name"]
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df["Name"].str.lower()
# Out:
# 0                                  kelly, mr. james
# 1                  wilkes, mrs. james (ellen needs)
# 2                         myles, mr. thomas francis
# 3                                  wirz, mr. albert
# 4      hirvonen, mrs. alexander (helga e lindqvist)
#                            ...
# 413                              spector, mr. woolf
# 414                    oliva y ocana, dona. fermina
# 415                    saether, mr. simon sivertsen
# 416                             ware, mr. frederick
# 417                        peter, master. michael j
# Name: Name, Length: 418, dtype: object

# %%
df["Name"].str.capitalize()
# Out:
# 0                                  Kelly, mr. james
# 1                  Wilkes, mrs. james (ellen needs)
# 2                         Myles, mr. thomas francis
# 3                                  Wirz, mr. albert
# 4      Hirvonen, mrs. alexander (helga e lindqvist)
#                            ...
# 413                              Spector, mr. woolf
# 414                    Oliva y ocana, dona. fermina
# 415                    Saether, mr. simon sivertsen
# 416                             Ware, mr. frederick
# 417                        Peter, master. michael j
# Name: Name, Length: 418, dtype: object

# %%
df["Name"].str.title()
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva Y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df["Name"].str.upper()
# Out:
# 0                                  KELLY, MR. JAMES
# 1                  WILKES, MRS. JAMES (ELLEN NEEDS)
# 2                         MYLES, MR. THOMAS FRANCIS
# 3                                  WIRZ, MR. ALBERT
# 4      HIRVONEN, MRS. ALEXANDER (HELGA E LINDQVIST)
#                            ...
# 413                              SPECTOR, MR. WOOLF
# 414                    OLIVA Y OCANA, DONA. FERMINA
# 415                    SAETHER, MR. SIMON SIVERTSEN
# 416                             WARE, MR. FREDERICK
# 417                        PETER, MASTER. MICHAEL J
# Name: Name, Length: 418, dtype: object

# %%
# avg fare  paid by malegroup and femalegroup
df.groupby(by='Sex')['Fare'].mean()
# Out:
# Sex
# female    49.747699
# male      27.527877
# Name: Fare, dtype: float64

# %%
df.groupby(by='Sex')['Fare'].mean()
# Out:
# Sex
# female    49.747699
# male      27.527877
# Name: Fare, dtype: float64

# %%
df.groupby(by='Sex')['Age'].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Sex
# female  127.0  30.272362  15.428613  0.17  20.5  27.0  38.5  76.0
# male    205.0  30.272732  13.389528  0.33  22.0  27.0  40.0  67.0

# %%
# length means  length of name
df["length"]=df["Name"].str.len()
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  check  length
# 0  34.5      0      0   330911   7.8292   NaN        Q    4.3      16
# 1  47.0      1      0   363272   7.0000   NaN        S    4.3      32
# 2  62.0      0      0   240276   9.6875   NaN        Q    4.3      25
# 3  27.0      0      0   315154   8.6625   NaN        S    4.3      16
# 4  22.0      1      1  3101298  12.2875   NaN        S    4.3      44

# %%
df10=df[df["Sex"].isin(["female"])]
df10.head()
# Out:
#     PassengerId  Pclass                                           Name  \
# 1           893       3               Wilkes, Mrs. James (Ellen Needs)
# 4           896       3   Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6           898       3                           Connolly, Miss. Kate
# 8           900       3      Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 12          904       1  Snyder, Mrs. John Pillsbury (Nelle Stevenson)
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked  check  length
# 1   female  47.0      1      0   363272   7.0000   NaN        S    4.3      32
# 4   female  22.0      1      1  3101298  12.2875   NaN        S    4.3      44
# 6   female  30.0      0      0   330972   7.6292   NaN        Q    4.3      20
# 8   female  18.0      0      0     2657   7.2292   NaN        C    4.3      41
# 12  female  23.0      1      0    21228  82.2667   B45        S    4.3      45

# %%
df11=df[df["Sex"].isin(["male"])]
df11.head()
# Out:
#    PassengerId  Pclass                          Name   Sex   Age  SibSp  \
# 0          892       3              Kelly, Mr. James  male  34.5      0
# 2          894       2     Myles, Mr. Thomas Francis  male  62.0      0
# 3          895       3              Wirz, Mr. Albert  male  27.0      0
# 5          897       3    Svensson, Mr. Johan Cervin  male  14.0      0
# 7          899       2  Caldwell, Mr. Albert Francis  male  26.0      1
#
#    Parch  Ticket     Fare Cabin Embarked  check  length
# 0      0  330911   7.8292   NaN        Q    4.3      16
# 2      0  240276   9.6875   NaN        Q    4.3      25
# 3      0  315154   8.6625   NaN        S    4.3      16
# 5      0    7538   9.2250   NaN        S    4.3      26
# 7      1  248738  29.0000   NaN        S    4.3      28

# %%
len(df11)
# Out:
# 266

# %%
plt.hist(df11["Age"],edgecolor="black")
# Out:
# (array([ 8.,  8., 21., 58., 42., 21., 20., 13.,  7.,  7.]),
#  array([ 0.33 ,  6.997, 13.664, 20.331, 26.998, 33.665, 40.332, 46.999,
#         53.666, 60.333, 67.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df10["Age"],edgecolor="black",label="Male")
plt.legend()

# %%
plt.scatter(df11["Age"],df11["Fare"],marker="o",color ="r")

# %%
plt.scatter(df11["Age"],df11["Fare"],marker="o",color ="r")

# %%
df10.isnull().any()
# Out:
# PassengerId    False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked       False
# check          False
# length         False
# dtype: bool

# %%
df11.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             61
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          219
# Embarked         0
# check            0
# length           0
# dtype: int64

# %%
## df10 =female
## df11=male

# %%
df11.drop(['Cabin'],axis=1,inplace=True)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# filling the fare 
# filling of data  is  knpown as imputing
df11["Fare"].fillna(df11["Fare"].mean(),inplace=True)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
df11.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# Age            61
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        0
# check           0
# length          0
# dtype: int64

# %%
61/len(df11)
# Out:
# 0.22932330827067668

# %%
len(df11)
# Out:
# 266

# %%
df110=df11.dropna(how="any",axis=0)

# %%
df110.head()
# Out:
#    PassengerId  Pclass                          Name   Sex   Age  SibSp  \
# 0          892       3              Kelly, Mr. James  male  34.5      0
# 2          894       2     Myles, Mr. Thomas Francis  male  62.0      0
# 3          895       3              Wirz, Mr. Albert  male  27.0      0
# 5          897       3    Svensson, Mr. Johan Cervin  male  14.0      0
# 7          899       2  Caldwell, Mr. Albert Francis  male  26.0      1
#
#    Parch  Ticket     Fare Embarked  check  length
# 0      0  330911   7.8292        Q    4.3      16
# 2      0  240276   9.6875        Q    4.3      25
# 3      0  315154   8.6625        S    4.3      16
# 5      0    7538   9.2250        S    4.3      26
# 7      1  248738  29.0000        S    4.3      28

# %%
len(df110)
# Out:
# 205

# %%
df10.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             25
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          108
# Embarked         0
# check            0
# length           0
# dtype: int64

# %%
df10.drop(['Cabin'],axis=1,inplace=True)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df10.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# Age            25
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        0
# check           0
# length          0
# dtype: int64

# %%
df100=df10.dropna(how="any",axis=0)
df100.head()
# Out:
#     PassengerId  Pclass                                           Name  \
# 1           893       3               Wilkes, Mrs. James (Ellen Needs)
# 4           896       3   Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6           898       3                           Connolly, Miss. Kate
# 8           900       3      Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 12          904       1  Snyder, Mrs. John Pillsbury (Nelle Stevenson)
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Embarked  check  length
# 1   female  47.0      1      0   363272   7.0000        S    4.3      32
# 4   female  22.0      1      1  3101298  12.2875        S    4.3      44
# 6   female  30.0      0      0   330972   7.6292        Q    4.3      20
# 8   female  18.0      0      0     2657   7.2292        C    4.3      41
# 12  female  23.0      1      0    21228  82.2667        S    4.3      45

# %%
len(df100)
# Out:
# 127

# %%
len(df10)
# Out:
# 152

# %%
# df100 = female
# df110= male

# %%
box_plot_data=[np.array(df110["Age"]),np.array(df110["Fare"])]
box_plot_data 
lbl=["Age",'Fare']
plt.figure(figsize=(10,6))
plt.boxplot(box_plot_data,labels=lbl);

# %%
box_plot_data=[np.array(df100["Age"]),np.array(df100["Fare"])]
box_plot_data
lbl=["Age",'Fare']
plt.figure(figsize=(10,6))
plt.boxplot(box_plot_data,labels=lbl);

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  check  length
# 0  34.5      0      0   330911   7.8292   NaN        Q    4.3      16
# 1  47.0      1      0   363272   7.0000   NaN        S    4.3      32
# 2  62.0      0      0   240276   9.6875   NaN        Q    4.3      25
# 3  27.0      0      0   315154   8.6625   NaN        S    4.3      16
# 4  22.0      1      1  3101298  12.2875   NaN        S    4.3      44

# %%
df["Gender"]=df["Name"].str.contains( )
df["Gender"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1256/1704730303.py in <module>
# ----> 1 df["Gender"]=df["Name"].str.contains( )
#       2 df["Gender"]
#
# NameError: name 'df' is not defined

# %%
df["Gender"]=df["Name"].str.contains('Mrs\.')
df["Gender"]
