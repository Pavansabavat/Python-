# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\DATA SCIENCE\\DATA ANALYSIS CLASS NOTES'

# %%
df=pd.read_excel(r"C:\\Users\\DELL\\DATA SCIENCE\\loandata.xlsx")

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %% [markdown]
# ### it works for both numeric and objects  to find values

# %%
income=df["ApplicantIncome"].values
income
# Out:
# array([  150,   210,   416,   645,   674,  1000,  1025,  1025,  1299,
#         1378,  1442,  1500,  1538,  1600,  1625,  1668,  1759,  1782,
#         1800,  1800,  1809,  1811,  1820,  1820,  1828,  1830,  1836,
#         1853,  1863,  1875,  1880,  1907,  1916,  1926,  1928,  1958,
#         1958,  1963,  1977,  1993,  2000,  2014,  2014,  2031,  2045,
#         2058,  2060,  2071,  2083,  2083,  2130,  2132,  2137,  2138,
#         2149,  2165,  2167,  2178,  2192,  2213,  2213,  2214,  2221,
#         2237,  2239,  2253,  2275,  2281,  2297,  2301,  2309,  2330,
#         2333,  2333,  2333,  2346,  2366,  2378,  2378,  2383,  2383,
#         2395,  2400,  2400,  2400,  2400,  2423,  2425,  2435,  2439,
#         2454,  2473,  2479,  2479,  2483,  2484,  2491,  2492,  2499,
#         2500,  2500,  2500,  2500,  2500,  2500,  2500,  2500,  2500,
#         2507,  2510,  2526,  2550,  2577,  2583,  2583,  2583,  2583,
# ...

# %%
education=df["Education"].values
education
# Out:
# array(['Graduate', 'Not Graduate', 'Graduate', 'Graduate', 'Graduate',
#        'Graduate', 'Graduate', 'Graduate', 'Graduate', 'Graduate',
#        'Not Graduate', 'Graduate', 'Graduate', 'Graduate', 'Graduate',
#        'Not Graduate', 'Graduate', 'Graduate', 'Graduate', 'Not Graduate',
#        'Graduate', 'Graduate', 'Not Graduate', 'Graduate', 'Graduate',
#        'Not Graduate', 'Graduate', 'Graduate', 'Not Graduate',
#        'Not Graduate', 'Graduate', 'Not Graduate', 'Graduate', 'Graduate',
#        'Not Graduate', 'Not Graduate', 'Not Graduate', 'Not Graduate',
#        'Graduate', 'Not Graduate', 'Not Graduate', 'Graduate', 'Graduate',
#        'Graduate', 'Graduate', 'Graduate', 'Graduate', 'Not Graduate',
#        'Graduate', 'Graduate', 'Graduate', 'Graduate', 'Graduate',
#        'Graduate', 'Not Graduate', 'Not Graduate', 'Not Graduate',
#        'Graduate', 'Not Graduate', 'Not Graduate', 'Graduate', 'Graduate',
# ...

# %%
income11=df["ApplicantIncome"].to_numpy()
income11
# Out:
# array([  150,   210,   416,   645,   674,  1000,  1025,  1025,  1299,
#         1378,  1442,  1500,  1538,  1600,  1625,  1668,  1759,  1782,
#         1800,  1800,  1809,  1811,  1820,  1820,  1828,  1830,  1836,
#         1853,  1863,  1875,  1880,  1907,  1916,  1926,  1928,  1958,
#         1958,  1963,  1977,  1993,  2000,  2014,  2014,  2031,  2045,
#         2058,  2060,  2071,  2083,  2083,  2130,  2132,  2137,  2138,
#         2149,  2165,  2167,  2178,  2192,  2213,  2213,  2214,  2221,
#         2237,  2239,  2253,  2275,  2281,  2297,  2301,  2309,  2330,
#         2333,  2333,  2333,  2346,  2366,  2378,  2378,  2383,  2383,
#         2395,  2400,  2400,  2400,  2400,  2423,  2425,  2435,  2439,
#         2454,  2473,  2479,  2479,  2483,  2484,  2491,  2492,  2499,
#         2500,  2500,  2500,  2500,  2500,  2500,  2500,  2500,  2500,
#         2507,  2510,  2526,  2550,  2577,  2583,  2583,  2583,  2583,
# ...

# %%
type(income11)
# Out:
# numpy.ndarray

# %% [markdown]
# ###  two  diff ways to convert to list

# %%
income11=list(df["ApplicantIncome"])
type(income11)
# Out:
# list

# %%
income11=df["ApplicantIncome"].tolist()
type(income11)
# Out:
# list

# %%
##  starts  from  first
df1=df.sort_values(by="CoapplicantIncome")
df1.head()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 306  LP001790  Female      No          1      Graduate            No
# 400  LP002161  Female      No          1      Graduate            No
# 397  LP001136    Male     Yes          0  Not Graduate           Yes
# 396  LP001097    Male      No          1      Graduate           Yes
# 395  LP002519    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 306             3812                0.0       112.0             360.0
# 400             4723                0.0        81.0             360.0
# 397             4695                0.0        96.0               NaN
# 396             4692                0.0       106.0             360.0
# 395             4691                0.0       100.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 306             1.0         Rural           Y
# ...

# %%
df1=df.sort_values(by="CoapplicantIncome",ascending=False)
df1.head()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 2    LP002949  Female      No         3+  Graduate           NaN
# 26   LP002893    Male      No          0  Graduate            No
# 105  LP002297    Male      No          0  Graduate            No
# 13   LP002342    Male     Yes          2  Graduate           Yes
# 446  LP001610    Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 2                416            41667.0       350.0             180.0
# 26              1836            33837.0        90.0             360.0
# 105             2500            20000.0       103.0             360.0
# 13              1600            20000.0       239.0             360.0
# 446             5516            11300.0       495.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 2               NaN         Urban           N
# 26              1.0         Urban           N
# ...

# %%
df1=df.sort_values(by="CoapplicantIncome",ascending=True)
df1.head()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 306  LP001790  Female      No          1      Graduate            No
# 400  LP002161  Female      No          1      Graduate            No
# 397  LP001136    Male     Yes          0  Not Graduate           Yes
# 396  LP001097    Male      No          1      Graduate           Yes
# 395  LP002519    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 306             3812                0.0       112.0             360.0
# 400             4723                0.0        81.0             360.0
# 397             4695                0.0        96.0               NaN
# 396             4692                0.0       106.0             360.0
# 395             4691                0.0       100.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 306             1.0         Rural           Y
# ...

# %% [markdown]
# ###  change  column name

# %%
df=df.rename(columns={"ApplicantIncome":"Income"})
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  Income  \
# 0  LP001722    Male     Yes          0      Graduate            No     150
# 1  LP002502  Female     Yes          2  Not Graduate           NaN     210
# 2  LP002949  Female      No         3+      Graduate           NaN     416
# 3  LP002603  Female      No          0      Graduate            No     645
# 4  LP001644     NaN     Yes          0      Graduate           Yes     674
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0             1800.0       135.0             360.0             1.0
# 1             2917.0        98.0             360.0             1.0
# 2            41667.0       350.0             180.0             NaN
# 3             3683.0       113.0             480.0             1.0
# 4             5296.0       168.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Rural           N
# 1     Semiurban           Y
# ...

# %% [markdown]
# ##   remove columns  which  donot want

# %%
df2=df.drop(columns=['Self_Employed','Credit_History'])
df2.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education  Income  \
# 0  LP001722    Male     Yes          0      Graduate     150
# 1  LP002502  Female     Yes          2  Not Graduate     210
# 2  LP002949  Female      No         3+      Graduate     416
# 3  LP002603  Female      No          0      Graduate     645
# 4  LP001644     NaN     Yes          0      Graduate     674
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area Loan_Status
# 0             1800.0       135.0             360.0         Rural           N
# 1             2917.0        98.0             360.0     Semiurban           Y
# 2            41667.0       350.0             180.0         Urban           N
# 3             3683.0       113.0             480.0         Rural           Y
# 4             5296.0       168.0             360.0         Rural           Y

# %%
##  delete rows with index 
## inplace=False   will not change in original   it will change in specified data frame
## inplace=true   will change in original  it

drop_rows=df.drop([0,2],inplace=False,axis=0)
drop_rows.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  Income  \
# 1  LP002502  Female     Yes          2  Not Graduate           NaN     210
# 3  LP002603  Female      No          0      Graduate            No     645
# 4  LP001644     NaN     Yes          0      Graduate           Yes     674
# 5  LP001259    Male     Yes          1      Graduate           Yes    1000
# 6  LP002345    Male     Yes          0      Graduate            No    1025
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             2917.0        98.0             360.0             1.0
# 3             3683.0       113.0             480.0             1.0
# 4             5296.0       168.0             360.0             1.0
# 5             3022.0       110.0             360.0             1.0
# 6             2773.0       112.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1     Semiurban           Y
# 3         Rural           Y
# ...

# %%
drop_rows=df.drop([0,2],axis=0)
drop_rows.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  Income  \
# 1  LP002502  Female     Yes          2  Not Graduate           NaN     210
# 3  LP002603  Female      No          0      Graduate            No     645
# 4  LP001644     NaN     Yes          0      Graduate           Yes     674
# 5  LP001259    Male     Yes          1      Graduate           Yes    1000
# 6  LP002345    Male     Yes          0      Graduate            No    1025
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             2917.0        98.0             360.0             1.0
# 3             3683.0       113.0             480.0             1.0
# 4             5296.0       168.0             360.0             1.0
# 5             3022.0       110.0             360.0             1.0
# 6             2773.0       112.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1     Semiurban           Y
# 3         Rural           Y
# ...

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Income', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.columns[[0,4,7]]
# Out:
# Index(['Loan_ID', 'Education', 'CoapplicantIncome'], dtype='object')

# %%
df2.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Income',
#        'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Property_Area',
#        'Loan_Status'],
#       dtype='object')

# %%
df2.drop(df.columns[[0,4,7]],axis=1,inplace=True)
df2.head()
# Out:
#    Gender Married Dependents  Income  LoanAmount  Loan_Amount_Term  \
# 0    Male     Yes          0     150       135.0             360.0
# 1  Female     Yes          2     210        98.0             360.0
# 2  Female      No         3+     416       350.0             180.0
# 3  Female      No          0     645       113.0             480.0
# 4     NaN     Yes          0     674       168.0             360.0
#
#   Property_Area Loan_Status
# 0         Rural           N
# 1     Semiurban           Y
# 2         Urban           N
# 3         Rural           Y
# 4         Rural           Y

# %%
##  alternative with out dropping
## !=   means  not equal to
df_not_male=df.loc[df["Gender"]!="Male"]
df_not_male
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  Income  \
# 1    LP002502  Female     Yes          2  Not Graduate           NaN     210
# 2    LP002949  Female      No         3+      Graduate           NaN     416
# 3    LP002603  Female      No          0      Graduate            No     645
# 4    LP001644     NaN     Yes          0      Graduate           Yes     674
# 9    LP001267  Female     Yes          2      Graduate            No    1378
# ..        ...     ...     ...        ...           ...           ...     ...
# 596  LP002582  Female      No          0  Not Graduate           Yes   17263
# 598  LP002731  Female      No          0  Not Graduate           Yes   18165
# 600  LP002813  Female     Yes          1      Graduate           Yes   19484
# 606  LP001448     NaN     Yes         3+      Graduate            No   23803
# 611  LP001585     NaN     Yes         3+      Graduate            No   51763
#
# ...

# %% [markdown]
# # GroupBy()

# %%
df.groupby(by="Gender")["Income"].mean()
# Out:
# Gender
# Female    4643.473214
# Male      5446.460123
# Name: Income, dtype: float64

# %%
df.groupby(by="Gender")["Income"].max()
# Out:
# Gender
# Female    19484
# Male      81000
# Name: Income, dtype: int64

# %%
df.groupby(by="Gender")["Income"].min()
# Out:
# Gender
# Female    210
# Male      150
# Name: Income, dtype: int64

# %%
df.groupby(by="Gender")["CoapplicantIncome"].mean()
# Out:
# Gender
# Female    1108.008929
# Male      1742.932352
# Name: CoapplicantIncome, dtype: float64

# %%
df.groupby(by="Gender")["CoapplicantIncome"].max()
# Out:
# Gender
# Female    41667.0
# Male      33837.0
# Name: CoapplicantIncome, dtype: float64

# %%
df.groupby(by="Gender")["CoapplicantIncome"].min()
# Out:
# Gender
# Female    0.0
# Male      0.0
# Name: CoapplicantIncome, dtype: float64

# %%
df.groupby(by="Gender")["LoanAmount"].max()
# Out:
# Gender
# Female    600.0
# Male      650.0
# Name: LoanAmount, dtype: float64

# %%
df.groupby(by="Education")["Income"].max()
# Out:
# Education
# Graduate        81000
# Not Graduate    18165
# Name: Income, dtype: int64

# %%
df.groupby(by="Education")["Income"].std()
# Out:
# Education
# Graduate        6739.797954
# Not Graduate    2237.081586
# Name: Income, dtype: float64

# %%
df.groupby(by="Education")["Income"].var()
# Out:
# Education
# Graduate        4.542488e+07
# Not Graduate    5.004534e+06
# Name: Income, dtype: float64

# %%
df.groupby(by="Education")["Income"].min()
# Out:
# Education
# Graduate        150
# Not Graduate    210
# Name: Income, dtype: int64

# %%
df.groupby(by="Gender")["LoanAmount","Income"].mean()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_14192/4291934875.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by="Gender")["LoanAmount","Income"].mean()
#         LoanAmount       Income
# Gender
# Female  126.697248  4643.473214
# Male    149.265957  5446.460123

# %%
df.groupby(by="Gender")["LoanAmount","Income"].max()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_14192/1037745020.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by="Gender")["LoanAmount","Income"].max()
#         LoanAmount  Income
# Gender
# Female       600.0   19484
# Male         650.0   81000

# %% [markdown]
# ## with out specifying  column name

# %%
df.groupby(by="Gender").mean()
# Out:
#              Income  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Gender
# Female  4643.473214        1108.008929  126.697248        352.293578
# Male    5446.460123        1742.932352  149.265957        339.665272
#
#         Credit_History
# Gender
# Female        0.831683
# Male          0.847007

# %%
df.groupby(by="Gender").max()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_14192/1459703201.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby(by="Gender").max()
#          Loan_ID     Education  Income  CoapplicantIncome  LoanAmount  \
# Gender
# Female  LP002990  Not Graduate   19484            41667.0       600.0
# Male    LP002984  Not Graduate   81000            33837.0       650.0
#
#         Loan_Amount_Term  Credit_History Property_Area Loan_Status
# Gender
# Female             480.0             1.0         Urban           Y
# Male               480.0             1.0         Urban           Y

# %% [markdown]
# ##  grouping my multiple columns

# %%
df.groupby(by=["Married","Gender"])["Income"].mean()
# Out:
# Married  Gender
# No       Female    4503.787500
#          Male      5236.146154
# Yes      Female    4829.645161
#          Male      5529.540616
# Name: Income, dtype: float64

# %%
df.groupby(by=["Married","Gender"])["Income","LoanAmount"].min()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_14192/787639336.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by=["Married","Gender"])["Income","LoanAmount"].min()
#                 Income  LoanAmount
# Married Gender
# No      Female     416         9.0
#         Male      1442        25.0
# Yes     Female     210        36.0
#         Male       150        17.0

# %%
df.groupby(by=["Married","Gender"])["Income"].max()
# Out:
# Married  Gender
# No       Female    18165
#          Male      37719
# Yes      Female    19484
#          Male      81000
# Name: Income, dtype: int64

# %%
df.groupby(by=["Married","Gender"])["Income","LoanAmount"].min()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_14192/787639336.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by=["Married","Gender"])["Income","LoanAmount"].min()
#                 Income  LoanAmount
# Married Gender
# No      Female     416         9.0
#         Male      1442        25.0
# Yes     Female     210        36.0
#         Male       150        17.0

# %%
df.groupby(by=["Gender","Married"]).mean()
# Out:
#                      Income  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Gender Married
# Female No       4503.787500        1020.012500  116.115385        355.012987
#        Yes      4829.645161        1370.838710  153.322581        349.161290
# Male   No       5236.146154        1529.430769  136.088000        348.562500
#        Yes      5529.540616        1828.330308  154.011662        335.931034
#
#                 Credit_History
# Gender Married
# Female No             0.821918
#        Yes            0.851852
# Male   No             0.845528
#        Yes            0.846626

# %%
df.groupby(by=["Gender","Married"]).max()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_14192/3730792107.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby(by=["Gender","Married"]).max()
#                  Loan_ID     Education  Income  CoapplicantIncome  LoanAmount  \
# Gender Married
# Female No       LP002990  Not Graduate   18165            41667.0       350.0
#        Yes      LP002959  Not Graduate   19484             4486.0       600.0
# Male   No       LP002958  Not Graduate   37719            33837.0       650.0
#        Yes      LP002984  Not Graduate   81000            20000.0       600.0
#
#                 Loan_Amount_Term  Credit_History Property_Area Loan_Status
# Gender Married
# Female No                  480.0             1.0         Urban           Y
#        Yes                 480.0             1.0         Urban           Y
# ...

# %% [markdown]
# ##  applying Numpy

# %%
import numpy as np

# %%
df.groupby(["Gender","Married"])["Gender"].agg([np.count_nonzero])
# Out:
#                 count_nonzero
# Gender Married
# Female No                  80
#        Yes                 31
# Male   No                 130
#        Yes                357

# %%
df.groupby(["Gender"])["LoanAmount"].agg([np.mean,np.max,np.std,np.min])
# Out:
#               mean   amax        std  amin
# Gender
# Female  126.697248  600.0  79.286460   9.0
# Male    149.265957  650.0  82.810851  17.0

# %%
df.groupby(["Gender","Married"])["LoanAmount"].agg([np.mean,np.max,np.std,np.min])
# Out:
#                       mean   amax         std  amin
# Gender Married
# Female No       116.115385  350.0   57.781042   9.0
#        Yes      153.322581  600.0  114.183883  36.0
# Male   No       136.088000  650.0   81.771516  25.0
#        Yes      154.011662  600.0   83.025254  17.0

# %%
d1=df.groupby(["Married","Gender"])
type(d1)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
d1

# %%
d1["Income"].mean().sort_values()
# Out:
# Married  Gender
# No       Female    4503.787500
# Yes      Female    4829.645161
# No       Male      5236.146154
# Yes      Male      5529.540616
# Name: Income, dtype: float64

# %%
d1["Income"].agg([np.mean,np.max,np.min])
# Out:
#                        mean   amax  amin
# Married Gender
# No      Female  4503.787500  18165   416
#         Male    5236.146154  37719  1442
# Yes     Female  4829.645161  19484   210
#         Male    5529.540616  81000   150

# %% [markdown]
# ## Crosstab

# %%
pd.crosstab(df["Gender"],df["Married"])
# Out:
# Married   No  Yes
# Gender
# Female    80   31
# Male     130  357

# %%
pd.crosstab(df["Gender"],df["Education"])
# Out:
# Education  Graduate  Not Graduate
# Gender
# Female           92            20
# Male            376           113

# %%
pd.crosstab(df.Gender,df.Married,values=df.Income,aggfunc="max")
# Out:
# Married     No    Yes
# Gender
# Female   18165  19484
# Male     37719  81000

# %%
pd.crosstab(df.Gender,df.Married,values=df.Income,aggfunc="min")
# Out:
# Married    No  Yes
# Gender
# Female    416  210
# Male     1442  150

# %%
## selecting  the column as index
df.set_index("Loan_ID",inplace=True)

# %%
df.head()
# Out:
#           Gender Married Dependents     Education Self_Employed  Income  \
# Loan_ID
# LP001722    Male     Yes          0      Graduate            No     150
# LP002502  Female     Yes          2  Not Graduate           NaN     210
# LP002949  Female      No         3+      Graduate           NaN     416
# LP002603  Female      No          0      Graduate            No     645
# LP001644     NaN     Yes          0      Graduate           Yes     674
#
#           CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# Loan_ID
# LP001722             1800.0       135.0             360.0             1.0
# LP002502             2917.0        98.0             360.0             1.0
# LP002949            41667.0       350.0             180.0             NaN
# LP002603             3683.0       113.0             480.0             1.0
# LP001644             5296.0       168.0             360.0             1.0
#
#          Property_Area Loan_Status
# Loan_ID
# ...
