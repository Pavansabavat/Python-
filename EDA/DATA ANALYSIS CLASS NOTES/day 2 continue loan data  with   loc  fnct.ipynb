# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\DATA SCIENCE\\DATA ANALYSIS CLASS NOTES'

# %%
df=pd.read_excel(r"C:\\Users\\DELL\\DATA SCIENCE\\loandata.xlsx")

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %%
df.iloc[0,0]
# Out:
# 'LP001722'

# %%
df.iloc[0,1]
# Out:
# 'Male'

# %%
df.iloc[2,3]
# Out:
# '3+'

# %%
df.iloc[3,1]
# Out:
# 'Female'

# %%
df.iloc[3,4]
# Out:
# 'Graduate'

# %%
df.iloc[1,4]
# Out:
# 'Not Graduate'

# %%
df.loc[2,"Gender"]
# Out:
# 'Female'

# %%
df.loc[3,"Married"]
# Out:
# 'No'

# %%
df.loc[3,"CoapplicantIncome"]
# Out:
# 3683.0

# %%
df.iloc[0:3,]
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# 2             NaN         Urban           N

# %%
## by default if u inddex [0:3]  it wil  use 0 to 3
df.loc[0:4]
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %%
df.iloc[0:3,2:4,]
# Out:
#   Married Dependents
# 0     Yes          0
# 1     Yes          2
# 2      No         3+

# %%
df.loc[0:3,["Gender","Dependents","Education"]]
# Out:
#    Gender Dependents     Education
# 0    Male          0      Graduate
# 1  Female          2  Not Graduate
# 2  Female         3+      Graduate
# 3  Female          0      Graduate

# %%
df.loc[0:3,"Gender":"Self_Employed"]
# Out:
#    Gender Married Dependents     Education Self_Employed
# 0    Male     Yes          0      Graduate            No
# 1  Female     Yes          2  Not Graduate           NaN
# 2  Female      No         3+      Graduate           NaN
# 3  Female      No          0      Graduate            No

# %%
## for all rows and specific column numbers
df.iloc[:, [0,5,7]]
# Out:
#       Loan_ID Self_Employed  CoapplicantIncome
# 0    LP001722            No             1800.0
# 1    LP002502           NaN             2917.0
# 2    LP002949           NaN            41667.0
# 3    LP002603            No             3683.0
# 4    LP001644           Yes             5296.0
# ..        ...           ...                ...
# 609  LP001640           Yes             4750.0
# 610  LP001536            No                0.0
# 611  LP001585            No                0.0
# 612  LP002101           NaN                0.0
# 613  LP002317            No                0.0
#
# [614 rows x 3 columns]

# %%
##  for specified rows and all columns
df.iloc[10:16,:]
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 10  LP001086    Male      No          0  Not Graduate            No
# 11  LP002287  Female      No          0      Graduate            No
# 12  LP001518    Male     Yes          1      Graduate            No
# 13  LP002342    Male     Yes          2      Graduate           Yes
# 14  LP001977    Male     Yes          1      Graduate            No
# 15  LP001835    Male     Yes          0  Not Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 10             1442                0.0        35.0             360.0
# 11             1500             1800.0       103.0             360.0
# 12             1538             1425.0        30.0             360.0
# 13             1600            20000.0       239.0             360.0
# 14             1625             1803.0        96.0             360.0
# 15             1668             3890.0       201.0             360.0
#
# ...

# %%
df[["Loan_ID","Education","Property_Area"]]
# Out:
#       Loan_ID     Education Property_Area
# 0    LP001722      Graduate         Rural
# 1    LP002502  Not Graduate     Semiurban
# 2    LP002949      Graduate         Urban
# 3    LP002603      Graduate         Rural
# 4    LP001644      Graduate         Rural
# ..        ...           ...           ...
# 609  LP001640      Graduate     Semiurban
# 610  LP001536      Graduate     Semiurban
# 611  LP001585      Graduate         Urban
# 612  LP002101      Graduate         Urban
# 613  LP002317      Graduate         Rural
#
# [614 rows x 3 columns]

# %%
## multiple columns
df1=df[["Gender","Loan_ID","Married"]]

# %%
df1.head()
# Out:
#    Gender   Loan_ID Married
# 0    Male  LP001722     Yes
# 1  Female  LP002502     Yes
# 2  Female  LP002949      No
# 3  Female  LP002603      No
# 4     NaN  LP001644     Yes

# %%
## modifying Data Frame
df1["Gender"][1]="Male"
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_8800/2179593361.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Gender"][1]="Male"

# %%
df1
# Out:
#      Gender   Loan_ID Married
# 0      Male  LP001722     Yes
# 1      Male  LP002502     Yes
# 2    Female  LP002949      No
# 3      Male  LP002603      No
# 4       NaN  LP001644     Yes
# ..      ...       ...     ...
# 609    Male  LP001640     Yes
# 610    Male  LP001536     Yes
# 611     NaN  LP001585     Yes
# 612    Male  LP002101     Yes
# 613    Male  LP002317     Yes
#
# [614 rows x 3 columns]

# %%
df1.iloc[3,0]="Male"
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
df1
# Out:
#      Gender   Loan_ID Married
# 0      Male  LP001722     Yes
# 1      Male  LP002502     Yes
# 2    Female  LP002949      No
# 3      Male  LP002603      No
# 4       NaN  LP001644     Yes
# ..      ...       ...     ...
# 609    Male  LP001640     Yes
# 610    Male  LP001536     Yes
# 611     NaN  LP001585     Yes
# 612    Male  LP002101     Yes
# 613    Male  LP002317     Yes
#
# [614 rows x 3 columns]

# %%
df1.head()
# Out:
#    Gender   Loan_ID Married
# 0    Male  LP001722     Yes
# 1    Male  LP002502     Yes
# 2  Female  LP002949      No
# 3    Male  LP002603      No
# 4     NaN  LP001644     Yes

# %%
df["Gender"]=="Male"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609     True
# 610     True
# 611    False
# 612     True
# 613     True
# Name: Gender, Length: 614, dtype: bool

# %%
df1=df.loc[df["Gender"]=="Male"]
df1
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001722   Male     Yes          0  Graduate            No
# 5    LP001259   Male     Yes          1  Graduate           Yes
# 6    LP002345   Male     Yes          0  Graduate            No
# 7    LP002717   Male     Yes          0  Graduate            No
# 8    LP001030   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 608  LP002422   Male      No          1  Graduate            No
# 609  LP001640   Male     Yes          0  Graduate           Yes
# 610  LP001536   Male     Yes         3+  Graduate            No
# 612  LP002101   Male     Yes          0  Graduate           NaN
# 613  LP002317   Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150             1800.0       135.0             360.0
# ...

# %%
df1=df.loc[df["Gender"]=="Female"]
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 9    LP001267  Female     Yes          2      Graduate            No
# 11   LP002287  Female      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 585  LP001516  Female     Yes          2      Graduate            No
# 589  LP002194  Female      No          0      Graduate           Yes
# 596  LP002582  Female      No          0  Not Graduate           Yes
# 598  LP002731  Female      No          0  Not Graduate           Yes
# 600  LP002813  Female     Yes          1      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df1=df.loc[df["Self_Employed"]=="Yes"]
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# 5    LP001259    Male     Yes          1      Graduate           Yes
# 13   LP002342    Male     Yes          2      Graduate           Yes
# 29   LP001245    Male     Yes          2  Not Graduate           Yes
# 48   LP002478     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 597  LP002699    Male     Yes          2      Graduate           Yes
# 598  LP002731  Female      No          0  Not Graduate           Yes
# 600  LP002813  Female     Yes          1      Graduate           Yes
# 602  LP001469    Male      No          0      Graduate           Yes
# 609  LP001640    Male     Yes          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df1=df.loc[df["Property_Area"]=="Rural"]
df1
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0    LP001722    Male     Yes          0  Graduate            No
# 3    LP002603  Female      No          0  Graduate            No
# 4    LP001644     NaN     Yes          0  Graduate           Yes
# 6    LP002345    Male     Yes          0  Graduate            No
# 7    LP002717    Male     Yes          0  Graduate            No
# ..        ...     ...     ...        ...       ...           ...
# 601  LP002191    Male     Yes          0  Graduate            No
# 603  LP001996    Male      No          0  Graduate            No
# 604  LP001922    Male     Yes          0  Graduate            No
# 606  LP001448     NaN     Yes         3+  Graduate            No
# 613  LP002317    Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150             1800.0       135.0             360.0
# ...

# %%
df3=df.loc[df["Gender"]=="Male",["Loan_ID","Gender"]]
df3
# Out:
#       Loan_ID Gender
# 0    LP001722   Male
# 5    LP001259   Male
# 6    LP002345   Male
# 7    LP002717   Male
# 8    LP001030   Male
# ..        ...    ...
# 608  LP002422   Male
# 609  LP001640   Male
# 610  LP001536   Male
# 612  LP002101   Male
# 613  LP002317   Male
#
# [489 rows x 2 columns]

# %%
df4=df.loc[df["Education"]=="Graduate",["Loan_ID","Gender","Education"]]
df4
# Out:
#       Loan_ID  Gender Education
# 0    LP001722    Male  Graduate
# 2    LP002949  Female  Graduate
# 3    LP002603  Female  Graduate
# 4    LP001644     NaN  Graduate
# 5    LP001259    Male  Graduate
# ..        ...     ...       ...
# 609  LP001640    Male  Graduate
# 610  LP001536    Male  Graduate
# 611  LP001585     NaN  Graduate
# 612  LP002101    Male  Graduate
# 613  LP002317    Male  Graduate
#
# [480 rows x 3 columns]

# %%
df.loc[df["ApplicantIncome"]<1000]
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %%
df5=df.loc[df["LoanAmount"]<1500]
df5
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df6=df.loc[(df["LoanAmount"]<1500) & (df["CoapplicantIncome"]>3000)]
df6
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 2    LP002949  Female      No         3+  Graduate           NaN
# 3    LP002603  Female      No          0  Graduate            No
# 4    LP001644     NaN     Yes          0  Graduate           Yes
# 5    LP001259    Male     Yes          1  Graduate           Yes
# 7    LP002717    Male     Yes          0  Graduate            No
# ..        ...     ...     ...        ...       ...           ...
# 566  LP001451    Male     Yes          1  Graduate           Yes
# 578  LP001020    Male     Yes          1  Graduate            No
# 601  LP002191    Male     Yes          0  Graduate            No
# 605  LP002624    Male     Yes          0  Graduate            No
# 609  LP001640    Male     Yes          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 2                416            41667.0       350.0             180.0
# ...

# %%
df6=df.loc[(df["Married"]=="No") & (df["Gender"]=="Female")&(df["Education"]=="Graduate")&(df["Property_Area"]=="Semiurban")]
df6
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 11   LP002287  Female      No          0  Graduate            No
# 52   LP001431  Female      No          0  Graduate            No
# 53   LP002743  Female      No          0  Graduate            No
# 120  LP001925  Female      No          0  Graduate           Yes
# 159  LP002002  Female      No          0  Graduate            No
# 192  LP001157  Female      No          0  Graduate            No
# 202  LP002606  Female      No          0  Graduate            No
# 258  LP001870  Female      No          1  Graduate            No
# 268  LP002043  Female      No          1  Graduate            No
# 282  LP002753  Female      No          1  Graduate           NaN
# 298  LP001087  Female      No          2  Graduate           NaN
# 311  LP001265  Female      No          0  Graduate            No
# 331  LP001151  Female      No          0  Graduate            No
# ...

# %%
len(df6)
# Out:
# 28

# %%
###  hom many people are married r have asked for loan amount more than 3000

# %%
df6=df.loc[(df["Married"]=="Yes") &  (df["LoanAmount"]>500)]
len(df6)
# df6
# Out:
# 4

# %%
df3["Gender"].unique()
# Out:
# array(['Male'], dtype=object)

# %%
df6=df.loc[(df["Married"]=="Yes") |  (df["LoanAmount"]>500)]
len(df6)
# Out:
# 399

# %%
df4=df.loc[(df["Gender"]=="Male")& (df["ApplicantIncome"]>10000),["Gender","LoanAmount"]]
df4.head()
# Out:
#     Gender  LoanAmount
# 563   Male       260.0
# 565   Male       187.0
# 566   Male       160.0
# 567   Male       312.0
# 568   Male       234.0

# %% [markdown]
# ### to ceate  new column

# %%
df["loan_years"]=df["Loan_Amount_Term"]/12
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status  loan_years
# 0             1.0         Rural           N        30.0
# ...

# %%
df["total_income"]=df["ApplicantIncome"]+df["CoapplicantIncome"]
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status  loan_years  total_income
# 0             1.0         Rural           N        30.0        1950.0
# ...
