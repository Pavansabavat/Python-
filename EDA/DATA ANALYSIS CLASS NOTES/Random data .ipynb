# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
# import warnings  
# warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\DELL\DATA SCIENCE\DATA ANALYSIS CLASS NOTES\random.csv")
df.head()
# Out:
#           x         y
# 0  0.645829  2.093071
# 1 -1.157771  1.786407
# 2 -0.813059 -0.712966
# 3  0.503495 -0.311660
# 4  1.766398  2.494042

# %%
sns.distplot(df['y'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='y', ylabel='Density'>

# %%
sns.histplot(df['y'])
# Out:
# <AxesSubplot:xlabel='y', ylabel='Count'>

# %%
sns.displot(df['y'])

# %%
sns.distplot(df['x'] , kde=False , rug=True)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='x'>

# %%
sns.distplot(df['x'] , kde=False, rug=False)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='x'>

# %%
# uni variet  analysis   means  single feature
# bi variet analysis  means two  features

# %% [markdown]
# ## bivariet plots

# %%
sns.jointplot(x='x',y='y',data=df,kind='scatter')

# %% [markdown]
# ### hexbin plots

# %%
sns.jointplot(x='x',y='y',data=df,kind='hex',color='b')

# %% [markdown]
# ###  pair plot

# %%
df1=pd.read_csv(r'C:\Users\DELL\DATA SCIENCE\DATA ANALYSIS CLASS NOTES\Iris.csv')

# %%
df1.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(df1)
# diagonal  are  univarient
#  and other mirror  are  bi variet

# %%
df1["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
sns.pairplot(df1,hue='Species')

# %%
d={'Name':pd.Series(['Tillu','mike','jp','narsimha','reddy','pavan','nikhil','bantu','mintu']),
   'Age':pd.Series([25,24,23,21,26,25,29,24,25]),
    'Rating':pd.Series([4.23,3.24,3.98,4.98,4.65,5.32,5.69,6.66,3.56])}
df=pd.DataFrame(d)
print(df)
print("Mean values of distibution")
print(df.mean())
print("***************************")
print("Median values of distibution")
print(df.median())
print("***************************")
print("Mode values of distibution")
print(df["Age"].mode())
# Out:
#        Name  Age  Rating
# 0     Tillu   25    4.23
# 1      mike   24    3.24
# 2        jp   23    3.98
# 3  narsimha   21    4.98
# 4     reddy   26    4.65
# 5     pavan   25    5.32
# 6    nikhil   29    5.69
# 7     bantu   24    6.66
# 8     mintu   25    3.56
# Mean values of distibution
# Age       24.666667
# Rating     4.701111
# dtype: float64
# ***************************
# Median values of distibution
# Age       25.00
# Rating     4.65
# dtype: float64
# ***************************
# Mode values of distibution
# 0    25
# dtype: int64
# C:\Users\DELL\AppData\Local\Temp/ipykernel_4024/1823794346.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df.mean())
# ...

# %%
sns.distplot(d["Age"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
# to calculate   outliers   for   lower   q1-1.5(iqr)
#  to  calculate upper outliers  is q3+1.5(iqr)

# %%
df.describe()
# Out:
#              Age    Rating
# count   9.000000  9.000000
# mean   24.666667  4.701111
# std     2.179449  1.087284
# min    21.000000  3.240000
# 25%    24.000000  3.980000
# 50%    25.000000  4.650000
# 75%    25.000000  5.320000
# max    29.000000  6.660000

# %%
df=pd.read_csv(r"C:\\Users\\DELL\\DATA SCIENCE\\DATA ANALYSIS CLASS NOTES\\tips.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
df.shape
# Out:
# (244, 7)

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# ## categorical  scatter plots-stripplot()

# %%
sns.stripplot(data=df,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## swarm plot

# %%
sns.swarmplot(data=df,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data=df,x='time',y='total_bill')
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
sns.swarmplot(data=df,x='day',y='tip')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(data=df,x='sex',y='tip')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(data=df,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=df,x='day',y='total_bill',hue='time')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data=df,x='day',y='total_bill',hue='time')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
titanic=pd.read_csv(r"C:\Users\DELL\DATA SCIENCE\DATA ANALYSIS CLASS NOTES\Titanic (2).csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
sns.boxplot(data=titanic,x="sex",y="age")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
plt.figure(figsize=(12,5))

plt.subplot(121)
sns.barplot(x="sex",y="age",data=titanic,estimator=np.mean)
plt.title('Avg Age')

plt.subplot(122)
sns.barplot(x="sex",y="age",data=titanic,estimator=np.median)
plt.title('Median Age')
# Out:
# Text(0.5, 1.0, 'Median Age')

# %%
sns.barplot(x='sex',y='survived',data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x='sex',y='survived',hue='class',data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %% [markdown]
# ## count plot

# %%
 sns.countplot(x='class',data=titanic,palette='Greens_d')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
 sns.countplot(x='survived',hue='sex',data=titanic,palette='Greens')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>
